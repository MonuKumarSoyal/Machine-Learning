# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt

pd.pandas.set_option("display.max_columns", None)

# %%
dataset_train = pd.read_csv("train.csv")
print(dataset_train.head())
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 1         Lvl    AllPub       FR2       Gtl      Veenker      Feedr
# 2         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 3         Lvl    AllPub    Corner       Gtl      Crawfor       Norm
# 4         Lvl    AllPub       FR2       Gtl      NoRidge       Norm
#
#   Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# 0       Norm     1Fam     2Story            7            5       2003
# 1       Norm     1Fam     1Story            6            8       1976
# 2       Norm     1Fam     2Story            7            5       2001
# 3       Norm     1Fam     2Story            7            5       1915
# 4       Norm     1Fam     2Story            8            5       2000
#
#    YearRemodAdd RoofStyle RoofMatl Exterior1st Exterior2nd MasVnrType  \
# 0          2003     Gable  CompShg     VinylSd     VinylSd    BrkFace
# 1          1976     Gable  CompShg     MetalSd     MetalSd       None
# 2          2002     Gable  CompShg     VinylSd     VinylSd    BrkFace
# 3          1970     Gable  CompShg     Wd Sdng     Wd Shng       None
# 4          2000     Gable  CompShg     VinylSd     VinylSd    BrkFace
#
#    MasVnrArea ExterQual ExterCond Foundation BsmtQual BsmtCond BsmtExposure  \
# 0       196.0        Gd        TA      PConc       Gd       TA           No
# 1         0.0        TA        TA     CBlock       Gd       TA           Gd
# 2       162.0        Gd        TA      PConc       Gd       TA           Mn
# 3         0.0        TA        TA     BrkTil       TA       Gd           No
# 4       350.0        Gd        TA      PConc       Gd       TA           Av
#
#   BsmtFinType1  BsmtFinSF1 BsmtFinType2  BsmtFinSF2  BsmtUnfSF  TotalBsmtSF  \
# 0          GLQ         706          Unf           0        150          856
# 1          ALQ         978          Unf           0        284         1262
# 2          GLQ         486          Unf           0        434          920
# 3          ALQ         216          Unf           0        540          756
# 4          GLQ         655          Unf           0        490         1145
#
#   Heating HeatingQC CentralAir Electrical  1stFlrSF  2ndFlrSF  LowQualFinSF  \
# 0    GasA        Ex          Y      SBrkr       856       854             0
# 1    GasA        Ex          Y      SBrkr      1262         0             0
# 2    GasA        Ex          Y      SBrkr       920       866             0
# 3    GasA        Gd          Y      SBrkr       961       756             0
# 4    GasA        Ex          Y      SBrkr      1145      1053             0
#
#    GrLivArea  BsmtFullBath  BsmtHalfBath  FullBath  HalfBath  BedroomAbvGr  \
# 0       1710             1             0         2         1             3
# 1       1262             0             1         2         0             3
# 2       1786             1             0         2         1             3
# 3       1717             1             0         1         0             3
# 4       2198             1             0         2         1             4
#
#    KitchenAbvGr KitchenQual  TotRmsAbvGrd Functional  Fireplaces FireplaceQu  \
# 0             1          Gd             8        Typ           0         NaN
# 1             1          TA             6        Typ           1          TA
# 2             1          Gd             6        Typ           1          TA
# 3             1          Gd             7        Typ           1          Gd
# 4             1          Gd             9        Typ           1          TA
#
#   GarageType  GarageYrBlt GarageFinish  GarageCars  GarageArea GarageQual  \
# 0     Attchd       2003.0          RFn           2         548         TA
# 1     Attchd       1976.0          RFn           2         460         TA
# 2     Attchd       2001.0          RFn           2         608         TA
# 3     Detchd       1998.0          Unf           3         642         TA
# 4     Attchd       2000.0          RFn           3         836         TA
#
#   GarageCond PavedDrive  WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  \
# 0         TA          Y           0           61              0          0
# 1         TA          Y         298            0              0          0
# 2         TA          Y           0           42              0          0
# 3         TA          Y           0           35            272          0
# 4         TA          Y         192           84              0          0
#
#    ScreenPorch  PoolArea PoolQC Fence MiscFeature  MiscVal  MoSold  YrSold  \
# 0            0         0    NaN   NaN         NaN        0       2    2008
# 1            0         0    NaN   NaN         NaN        0       5    2007
# 2            0         0    NaN   NaN         NaN        0       9    2008
# 3            0         0    NaN   NaN         NaN        0       2    2006
# 4            0         0    NaN   NaN         NaN        0      12    2008
#
#   SaleType SaleCondition  SalePrice
# 0       WD        Normal     208500
# 1       WD        Normal     181500
# 2       WD        Normal     223500
# 3       WD       Abnorml     140000
# 4       WD        Normal     250000

# %%
dataset_test = pd.read_csv("test.csv")
dataset_test.shape
# Out:
# (1459, 81)

# %%
# storing the categorical feature containing nan values in dataset_train

categorical_feature_for_train = [feature for feature in dataset_train.columns if dataset_train[feature].isnull().sum()>1 and dataset_train[feature].dtypes == "O"]
len(categorical_feature_for_train)
categorical_feature_for_train
# Out:
# ['Alley',
#  'MasVnrType',
#  'BsmtQual',
#  'BsmtCond',
#  'BsmtExposure',
#  'BsmtFinType1',
#  'BsmtFinType2',
#  'FireplaceQu',
#  'GarageType',
#  'GarageFinish',
#  'GarageQual',
#  'GarageCond',
#  'PoolQC',
#  'Fence',
#  'MiscFeature']

# %%
dataset_train[categorical_feature_for_train].isnull().sum()
# Out:
# Alley           1369
# MasVnrType         8
# BsmtQual          37
# BsmtCond          37
# BsmtExposure      38
# BsmtFinType1      37
# BsmtFinType2      38
# FireplaceQu      690
# GarageType        81
# GarageFinish      81
# GarageQual        81
# GarageCond        81
# PoolQC          1453
# Fence           1179
# MiscFeature     1406
# dtype: int64

# %%
# storing the categorical features containing nan values in dataset_test

categorical_feature_for_test = [feature for feature in dataset_test.columns if dataset_test[feature].isnull().sum()>1 and dataset_test[feature].dtypes == "O"]
len(categorical_feature_for_test)
categorical_feature_for_test
# Out:
# ['MSZoning',
#  'Alley',
#  'Utilities',
#  'MasVnrType',
#  'BsmtQual',
#  'BsmtCond',
#  'BsmtExposure',
#  'BsmtFinType1',
#  'BsmtFinType2',
#  'Functional',
#  'FireplaceQu',
#  'GarageType',
#  'GarageFinish',
#  'GarageQual',
#  'GarageCond',
#  'PoolQC',
#  'Fence',
#  'MiscFeature']

# %%
dataset_test[categorical_feature_for_test].isnull().sum()
# Out:
# MSZoning           4
# Alley           1352
# Utilities          2
# MasVnrType        16
# BsmtQual          44
# BsmtCond          45
# BsmtExposure      44
# BsmtFinType1      42
# BsmtFinType2      42
# Functional         2
# FireplaceQu      730
# GarageType        76
# GarageFinish      78
# GarageQual        78
# GarageCond        78
# PoolQC          1456
# Fence           1169
# MiscFeature     1408
# dtype: int64

# %%
dataset_test.head()
# Out:
#      Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0  1461          20       RH         80.0    11622   Pave   NaN      Reg
# 1  1462          20       RL         81.0    14267   Pave   NaN      IR1
# 2  1463          60       RL         74.0    13830   Pave   NaN      IR1
# 3  1464          60       RL         78.0     9978   Pave   NaN      IR1
# 4  1465         120       RL         43.0     5005   Pave   NaN      IR1
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl        NAmes      Feedr
# 1         Lvl    AllPub    Corner       Gtl        NAmes       Norm
# 2         Lvl    AllPub    Inside       Gtl      Gilbert       Norm
# 3         Lvl    AllPub    Inside       Gtl      Gilbert       Norm
# 4         HLS    AllPub    Inside       Gtl      StoneBr       Norm
#
#   Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# 0       Norm     1Fam     1Story            5            6       1961
# 1       Norm     1Fam     1Story            6            6       1958
# 2       Norm     1Fam     2Story            5            5       1997
# 3       Norm     1Fam     2Story            6            6       1998
# 4       Norm   TwnhsE     1Story            8            5       1992
#
#    YearRemodAdd RoofStyle RoofMatl Exterior1st Exterior2nd MasVnrType  \
# 0          1961     Gable  CompShg     VinylSd     VinylSd       None
# 1          1958       Hip  CompShg     Wd Sdng     Wd Sdng    BrkFace
# 2          1998     Gable  CompShg     VinylSd     VinylSd       None
# 3          1998     Gable  CompShg     VinylSd     VinylSd    BrkFace
# 4          1992     Gable  CompShg     HdBoard     HdBoard       None
#
#    MasVnrArea ExterQual ExterCond Foundation BsmtQual BsmtCond BsmtExposure  \
# 0         0.0        TA        TA     CBlock       TA       TA           No
# 1       108.0        TA        TA     CBlock       TA       TA           No
# 2         0.0        TA        TA      PConc       Gd       TA           No
# 3        20.0        TA        TA      PConc       TA       TA           No
# 4         0.0        Gd        TA      PConc       Gd       TA           No
#
#   BsmtFinType1  BsmtFinSF1 BsmtFinType2  BsmtFinSF2  BsmtUnfSF  TotalBsmtSF  \
# 0          Rec       468.0          LwQ       144.0      270.0        882.0
# 1          ALQ       923.0          Unf         0.0      406.0       1329.0
# 2          GLQ       791.0          Unf         0.0      137.0        928.0
# 3          GLQ       602.0          Unf         0.0      324.0        926.0
# 4          ALQ       263.0          Unf         0.0     1017.0       1280.0
#
#   Heating HeatingQC CentralAir Electrical  1stFlrSF  2ndFlrSF  LowQualFinSF  \
# 0    GasA        TA          Y      SBrkr       896         0             0
# 1    GasA        TA          Y      SBrkr      1329         0             0
# 2    GasA        Gd          Y      SBrkr       928       701             0
# 3    GasA        Ex          Y      SBrkr       926       678             0
# 4    GasA        Ex          Y      SBrkr      1280         0             0
#
#    GrLivArea  BsmtFullBath  BsmtHalfBath  FullBath  HalfBath  BedroomAbvGr  \
# 0        896           0.0           0.0         1         0             2
# 1       1329           0.0           0.0         1         1             3
# 2       1629           0.0           0.0         2         1             3
# 3       1604           0.0           0.0         2         1             3
# 4       1280           0.0           0.0         2         0             2
#
#    KitchenAbvGr KitchenQual  TotRmsAbvGrd Functional  Fireplaces FireplaceQu  \
# 0             1          TA             5        Typ           0         NaN
# 1             1          Gd             6        Typ           0         NaN
# 2             1          TA             6        Typ           1          TA
# 3             1          Gd             7        Typ           1          Gd
# 4             1          Gd             5        Typ           0         NaN
#
#   GarageType  GarageYrBlt GarageFinish  GarageCars  GarageArea GarageQual  \
# 0     Attchd       1961.0          Unf         1.0       730.0         TA
# 1     Attchd       1958.0          Unf         1.0       312.0         TA
# 2     Attchd       1997.0          Fin         2.0       482.0         TA
# 3     Attchd       1998.0          Fin         2.0       470.0         TA
# 4     Attchd       1992.0          RFn         2.0       506.0         TA
#
#   GarageCond PavedDrive  WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  \
# 0         TA          Y         140            0              0          0
# 1         TA          Y         393           36              0          0
# 2         TA          Y         212           34              0          0
# 3         TA          Y         360           36              0          0
# 4         TA          Y           0           82              0          0
#
#    ScreenPorch  PoolArea PoolQC  Fence MiscFeature  MiscVal  MoSold  YrSold  \
# 0          120         0    NaN  MnPrv         NaN        0       6    2010
# 1            0         0    NaN    NaN        Gar2    12500       6    2010
# 2            0         0    NaN  MnPrv         NaN        0       3    2010
# 3            0         0    NaN    NaN         NaN        0       6    2010
# 4          144         0    NaN    NaN         NaN        0       1    2010
#
#   SaleType SaleCondition  SalePrice
# 0       WD        Normal     208500
# 1       WD        Normal     181500
# 2       WD        Normal     223500
# 3       WD        Normal     140000
# 4       WD        Normal     250000

# %%
for feature in categorical_feature_for_train:
    data = dataset_train.copy()
    
    print("In {} missing values are ----> {} %".format(feature, np.round(dataset_train[feature].isnull().mean()*100, 4)))
# Out:
# In Alley missing values are ----> 93.7671 %
# In MasVnrType missing values are ----> 0.5479 %
# In BsmtQual missing values are ----> 2.5342 %
# In BsmtCond missing values are ----> 2.5342 %
# In BsmtExposure missing values are ----> 2.6027 %
# In BsmtFinType1 missing values are ----> 2.5342 %
# In BsmtFinType2 missing values are ----> 2.6027 %
# In FireplaceQu missing values are ----> 47.2603 %
# In GarageType missing values are ----> 5.5479 %
# In GarageFinish missing values are ----> 5.5479 %
# In GarageQual missing values are ----> 5.5479 %
# In GarageCond missing values are ----> 5.5479 %
# In PoolQC missing values are ----> 99.5205 %
# In Fence missing values are ----> 80.7534 %
# In MiscFeature missing values are ----> 96.3014 %

# %%
for feature in categorical_feature_for_test:    
    print("In {} missing values are ----> {} %".format(feature, np.round(dataset_test[feature].isnull().mean(), 4)))
# Out:
# In MSZoning missing values are ----> 0.0027 %
# In Alley missing values are ----> 0.9267 %
# In Utilities missing values are ----> 0.0014 %
# In MasVnrType missing values are ----> 0.011 %
# In BsmtQual missing values are ----> 0.0302 %
# In BsmtCond missing values are ----> 0.0308 %
# In BsmtExposure missing values are ----> 0.0302 %
# In BsmtFinType1 missing values are ----> 0.0288 %
# In BsmtFinType2 missing values are ----> 0.0288 %
# In Functional missing values are ----> 0.0014 %
# In FireplaceQu missing values are ----> 0.5003 %
# In GarageType missing values are ----> 0.0521 %
# In GarageFinish missing values are ----> 0.0535 %
# In GarageQual missing values are ----> 0.0535 %
# In GarageCond missing values are ----> 0.0535 %
# In PoolQC missing values are ----> 0.9979 %
# In Fence missing values are ----> 0.8012 %
# In MiscFeature missing values are ----> 0.965 %

# %%
for feature in categorical_feature_for_train:
    # data = dataset_train.copy()
    dataset_train[feature] = dataset_train[feature].fillna("Missing")
    

dataset_train[categorical_feature_for_train].isnull().sum() # now we will get 0 as output for each categorical feature since we have removed all the missing values
# Out:
# Alley           0
# MasVnrType      0
# BsmtQual        0
# BsmtCond        0
# BsmtExposure    0
# BsmtFinType1    0
# BsmtFinType2    0
# FireplaceQu     0
# GarageType      0
# GarageFinish    0
# GarageQual      0
# GarageCond      0
# PoolQC          0
# Fence           0
# MiscFeature     0
# dtype: int64

# %%
for feature in categorical_feature_for_test:
    dataset_test[feature] = dataset_test[feature].fillna("Missing")
    

dataset_test[categorical_feature_for_test].isnull().sum() # now we will get 0 as output for each categorical feature since we have removed all the missing values
# Out:
# MSZoning        0
# Alley           0
# Utilities       0
# MasVnrType      0
# BsmtQual        0
# BsmtCond        0
# BsmtExposure    0
# BsmtFinType1    0
# BsmtFinType2    0
# Functional      0
# FireplaceQu     0
# GarageType      0
# GarageFinish    0
# GarageQual      0
# GarageCond      0
# PoolQC          0
# Fence           0
# MiscFeature     0
# dtype: int64

# %%
dataset_train[categorical_feature_for_train].head()
# Out:
#      Alley MasVnrType BsmtQual BsmtCond BsmtExposure BsmtFinType1  \
# 0  Missing    BrkFace       Gd       TA           No          GLQ
# 1  Missing       None       Gd       TA           Gd          ALQ
# 2  Missing    BrkFace       Gd       TA           Mn          GLQ
# 3  Missing       None       TA       Gd           No          ALQ
# 4  Missing    BrkFace       Gd       TA           Av          GLQ
#
#   BsmtFinType2 FireplaceQu GarageType GarageFinish GarageQual GarageCond  \
# 0          Unf     Missing     Attchd          RFn         TA         TA
# 1          Unf          TA     Attchd          RFn         TA         TA
# 2          Unf          TA     Attchd          RFn         TA         TA
# 3          Unf          Gd     Detchd          Unf         TA         TA
# 4          Unf          TA     Attchd          RFn         TA         TA
#
#     PoolQC    Fence MiscFeature
# 0  Missing  Missing     Missing
# 1  Missing  Missing     Missing
# 2  Missing  Missing     Missing
# 3  Missing  Missing     Missing
# 4  Missing  Missing     Missing

# %%
dataset_test[categorical_feature_for_test].head()
# Out:
#   MSZoning    Alley Utilities MasVnrType BsmtQual BsmtCond BsmtExposure  \
# 0       RH  Missing    AllPub       None       TA       TA           No
# 1       RL  Missing    AllPub    BrkFace       TA       TA           No
# 2       RL  Missing    AllPub       None       Gd       TA           No
# 3       RL  Missing    AllPub    BrkFace       TA       TA           No
# 4       RL  Missing    AllPub       None       Gd       TA           No
#
#   BsmtFinType1 BsmtFinType2 Functional FireplaceQu GarageType GarageFinish  \
# 0          Rec          LwQ        Typ     Missing     Attchd          Unf
# 1          ALQ          Unf        Typ     Missing     Attchd          Unf
# 2          GLQ          Unf        Typ          TA     Attchd          Fin
# 3          GLQ          Unf        Typ          Gd     Attchd          Fin
# 4          ALQ          Unf        Typ     Missing     Attchd          RFn
#
#   GarageQual GarageCond   PoolQC    Fence MiscFeature
# 0         TA         TA  Missing    MnPrv     Missing
# 1         TA         TA  Missing  Missing        Gar2
# 2         TA         TA  Missing    MnPrv     Missing
# 3         TA         TA  Missing  Missing     Missing
# 4         TA         TA  Missing  Missing     Missing

# %%
# handling the missing values for numerical features in dataset_train

numerical_feature_for_train = [feature for feature in dataset_train.columns if dataset_train[feature].isnull().sum()>1 and dataset_train[feature].dtypes != "O"]
numerical_feature_for_train
# Out:
# ['LotFrontage', 'MasVnrArea', 'GarageYrBlt']

# %%
# handling the missing values for numerical features in dataset_test

numerical_feature_for_test = [feature for feature in dataset_test.columns if dataset_test[feature].isnull().sum()>1 and dataset_test[feature].dtypes != "O"]
numerical_feature_for_test
# Out:
# ['LotFrontage', 'MasVnrArea', 'BsmtFullBath', 'BsmtHalfBath', 'GarageYrBlt']

# %%
for feature in numerical_feature_for_train:
    print("In {} missing values are ----> {} %".format(feature, np.round(dataset_train[feature].isnull().mean(), 4)))
# Out:
# In LotFrontage missing values are ----> 0.1774 %
# In MasVnrArea missing values are ----> 0.0055 %
# In GarageYrBlt missing values are ----> 0.0555 %

# %%
for feature in numerical_feature_for_test:
    print("In {} missing values are ----> {} %".format(feature, np.round(dataset_test[feature].isnull().mean(), 4)))
# Out:
# In LotFrontage missing values are ----> 0.1556 %
# In MasVnrArea missing values are ----> 0.0103 %
# In BsmtFullBath missing values are ----> 0.0014 %
# In BsmtHalfBath missing values are ----> 0.0014 %
# In GarageYrBlt missing values are ----> 0.0535 %

# %%
# for replacing the missing values with median in dataset_train

def replace_nan_value(dataset_train, numerical_feature_for_train):
    data = dataset_test.copy()
    for feature in numerical_feature_for_train:
        median_value = data[feature].median()
        data[feature] = data[feature].fillna(median_value)
    return data

dataset_train = replace_nan_value(dataset_train, numerical_feature_for_train)
# dataset_train[numerical_feature_for_train].head()
dataset_train[numerical_feature_for_train].isnull().sum()
# Out:
# LotFrontage    0
# MasVnrArea     0
# GarageYrBlt    0
# dtype: int64

# %%
# for replacing the missing values with median in dataset_test

def replace_nan_value(dataset_test, numerical_feature_for_test):
    data = dataset_test.copy()
    for feature in numerical_feature_for_test:
        median_value = data[feature].median()
        data[feature] = data[feature].fillna(median_value)
    return data

dataset_test = replace_nan_value(dataset_train, numerical_feature_for_test)
# dataset_test[numerical_feature_for_test].head()
dataset_test[numerical_feature_for_test].isnull().sum()
# Out:
# LotFrontage     0
# MasVnrArea      0
# BsmtFullBath    0
# BsmtHalfBath    0
# GarageYrBlt     0
# dtype: int64

# %%
temporal_feature = [feature for feature in dataset_train.columns if "Yr" in feature or "Year" in feature]
temporal_feature
# Out:
# ['YearBuilt', 'YearRemodAdd', 'GarageYrBlt', 'YrSold']

# %%
for feature in temporal_feature:
    if feature != "YrSold":
        dataset_train[feature] = dataset_train["YrSold"] - dataset_train[feature]

# %%
dataset_train[temporal_feature].head()
# Out:
#    YearBuilt  YearRemodAdd  GarageYrBlt  YrSold
# 0         49            49         49.0    2010
# 1         52            52         52.0    2010
# 2         13            12         13.0    2010
# 3         12            12         12.0    2010
# 4         18            18         18.0    2010

# %%
# below is to find the feature in dataset_train which are numerical and doesn't contain 0 inside it

feature_for_log_trans_train = [feature for feature in dataset_train.columns if 0 not in dataset_train[feature].unique() and dataset_train[feature].dtypes != "O"]
feature_for_log_trans_train
# Out:
# ['Id',
#  'MSSubClass',
#  'LotFrontage',
#  'LotArea',
#  'OverallQual',
#  'OverallCond',
#  '1stFlrSF',
#  'GrLivArea',
#  'TotRmsAbvGrd',
#  'MoSold',
#  'YrSold',
#  'SalePrice']

# %%
len(feature_for_log_trans_train)
# Out:
# 12

# %%
# below is to store the features from dataset_test which are numerical and do not contain 0 inside it 

feature_for_log_trans_test = [feature for feature in dataset_test.columns if 0 not in dataset_test[feature].unique() and dataset_test[feature].dtypes != "O"]
feature_for_log_trans_test
# Out:
# ['Id',
#  'MSSubClass',
#  'LotFrontage',
#  'LotArea',
#  'OverallQual',
#  'OverallCond',
#  'YearBuilt',
#  'YearRemodAdd',
#  '1stFlrSF',
#  'GrLivArea',
#  'TotRmsAbvGrd',
#  'GarageYrBlt',
#  'MoSold',
#  'YrSold',
#  'SalePrice']

# %%
len(feature_for_log_trans_test)
# Out:
# 15

# %%
# below list is to contain some features for logrithmic transformation

log_transform = ['LotFrontage', 'LotArea', '1stFlrSF', 'GrLivArea', 'SalePrice']
log_transform
# Out:
# ['LotFrontage', 'LotArea', '1stFlrSF', 'GrLivArea', 'SalePrice']

# %%
dataset_test.head()
# Out:
#      Id  MSSubClass MSZoning  LotFrontage  LotArea Street    Alley LotShape  \
# 0  1461          20       RH         80.0    11622   Pave  Missing      Reg
# 1  1462          20       RL         81.0    14267   Pave  Missing      IR1
# 2  1463          60       RL         74.0    13830   Pave  Missing      IR1
# 3  1464          60       RL         78.0     9978   Pave  Missing      IR1
# 4  1465         120       RL         43.0     5005   Pave  Missing      IR1
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl        NAmes      Feedr
# 1         Lvl    AllPub    Corner       Gtl        NAmes       Norm
# 2         Lvl    AllPub    Inside       Gtl      Gilbert       Norm
# 3         Lvl    AllPub    Inside       Gtl      Gilbert       Norm
# 4         HLS    AllPub    Inside       Gtl      StoneBr       Norm
#
#   Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# 0       Norm     1Fam     1Story            5            6       1961
# 1       Norm     1Fam     1Story            6            6       1958
# 2       Norm     1Fam     2Story            5            5       1997
# 3       Norm     1Fam     2Story            6            6       1998
# 4       Norm   TwnhsE     1Story            8            5       1992
#
#    YearRemodAdd RoofStyle RoofMatl Exterior1st Exterior2nd MasVnrType  \
# 0          1961     Gable  CompShg     VinylSd     VinylSd       None
# 1          1958       Hip  CompShg     Wd Sdng     Wd Sdng    BrkFace
# 2          1998     Gable  CompShg     VinylSd     VinylSd       None
# 3          1998     Gable  CompShg     VinylSd     VinylSd    BrkFace
# 4          1992     Gable  CompShg     HdBoard     HdBoard       None
#
#    MasVnrArea ExterQual ExterCond Foundation BsmtQual BsmtCond BsmtExposure  \
# 0         0.0        TA        TA     CBlock       TA       TA           No
# 1       108.0        TA        TA     CBlock       TA       TA           No
# 2         0.0        TA        TA      PConc       Gd       TA           No
# 3        20.0        TA        TA      PConc       TA       TA           No
# 4         0.0        Gd        TA      PConc       Gd       TA           No
#
#   BsmtFinType1  BsmtFinSF1 BsmtFinType2  BsmtFinSF2  BsmtUnfSF  TotalBsmtSF  \
# 0          Rec       468.0          LwQ       144.0      270.0        882.0
# 1          ALQ       923.0          Unf         0.0      406.0       1329.0
# 2          GLQ       791.0          Unf         0.0      137.0        928.0
# 3          GLQ       602.0          Unf         0.0      324.0        926.0
# 4          ALQ       263.0          Unf         0.0     1017.0       1280.0
#
#   Heating HeatingQC CentralAir Electrical  1stFlrSF  2ndFlrSF  LowQualFinSF  \
# 0    GasA        TA          Y      SBrkr       896         0             0
# 1    GasA        TA          Y      SBrkr      1329         0             0
# 2    GasA        Gd          Y      SBrkr       928       701             0
# 3    GasA        Ex          Y      SBrkr       926       678             0
# 4    GasA        Ex          Y      SBrkr      1280         0             0
#
#    GrLivArea  BsmtFullBath  BsmtHalfBath  FullBath  HalfBath  BedroomAbvGr  \
# 0        896           0.0           0.0         1         0             2
# 1       1329           0.0           0.0         1         1             3
# 2       1629           0.0           0.0         2         1             3
# 3       1604           0.0           0.0         2         1             3
# 4       1280           0.0           0.0         2         0             2
#
#    KitchenAbvGr KitchenQual  TotRmsAbvGrd Functional  Fireplaces FireplaceQu  \
# 0             1          TA             5        Typ           0     Missing
# 1             1          Gd             6        Typ           0     Missing
# 2             1          TA             6        Typ           1          TA
# 3             1          Gd             7        Typ           1          Gd
# 4             1          Gd             5        Typ           0     Missing
#
#   GarageType  GarageYrBlt GarageFinish  GarageCars  GarageArea GarageQual  \
# 0     Attchd       1961.0          Unf         1.0       730.0         TA
# 1     Attchd       1958.0          Unf         1.0       312.0         TA
# 2     Attchd       1997.0          Fin         2.0       482.0         TA
# 3     Attchd       1998.0          Fin         2.0       470.0         TA
# 4     Attchd       1992.0          RFn         2.0       506.0         TA
#
#   GarageCond PavedDrive  WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  \
# 0         TA          Y         140            0              0          0
# 1         TA          Y         393           36              0          0
# 2         TA          Y         212           34              0          0
# 3         TA          Y         360           36              0          0
# 4         TA          Y           0           82              0          0
#
#    ScreenPorch  PoolArea   PoolQC    Fence MiscFeature  MiscVal  MoSold  \
# 0          120         0  Missing    MnPrv     Missing        0       6
# 1            0         0  Missing  Missing        Gar2    12500       6
# 2            0         0  Missing    MnPrv     Missing        0       3
# 3            0         0  Missing  Missing     Missing        0       6
# 4          144         0  Missing  Missing     Missing        0       1
#
#    YrSold SaleType SaleCondition  SalePrice
# 0    2010       WD        Normal     208500
# 1    2010       WD        Normal     181500
# 2    2010       WD        Normal     223500
# 3    2010       WD        Normal     140000
# 4    2010       WD        Normal     250000

# %%
dataset_train.head()
# Out:
#      Id  MSSubClass MSZoning  LotFrontage  LotArea Street    Alley LotShape  \
# 0  1461          20       RH         80.0    11622   Pave  Missing      Reg
# 1  1462          20       RL         81.0    14267   Pave  Missing      IR1
# 2  1463          60       RL         74.0    13830   Pave  Missing      IR1
# 3  1464          60       RL         78.0     9978   Pave  Missing      IR1
# 4  1465         120       RL         43.0     5005   Pave  Missing      IR1
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl        NAmes      Feedr
# 1         Lvl    AllPub    Corner       Gtl        NAmes       Norm
# 2         Lvl    AllPub    Inside       Gtl      Gilbert       Norm
# 3         Lvl    AllPub    Inside       Gtl      Gilbert       Norm
# 4         HLS    AllPub    Inside       Gtl      StoneBr       Norm
#
#   Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# 0       Norm     1Fam     1Story            5            6         49
# 1       Norm     1Fam     1Story            6            6         52
# 2       Norm     1Fam     2Story            5            5         13
# 3       Norm     1Fam     2Story            6            6         12
# 4       Norm   TwnhsE     1Story            8            5         18
#
#    YearRemodAdd RoofStyle RoofMatl Exterior1st Exterior2nd MasVnrType  \
# 0            49     Gable  CompShg     VinylSd     VinylSd       None
# 1            52       Hip  CompShg     Wd Sdng     Wd Sdng    BrkFace
# 2            12     Gable  CompShg     VinylSd     VinylSd       None
# 3            12     Gable  CompShg     VinylSd     VinylSd    BrkFace
# 4            18     Gable  CompShg     HdBoard     HdBoard       None
#
#    MasVnrArea ExterQual ExterCond Foundation BsmtQual BsmtCond BsmtExposure  \
# 0         0.0        TA        TA     CBlock       TA       TA           No
# 1       108.0        TA        TA     CBlock       TA       TA           No
# 2         0.0        TA        TA      PConc       Gd       TA           No
# 3        20.0        TA        TA      PConc       TA       TA           No
# 4         0.0        Gd        TA      PConc       Gd       TA           No
#
#   BsmtFinType1  BsmtFinSF1 BsmtFinType2  BsmtFinSF2  BsmtUnfSF  TotalBsmtSF  \
# 0          Rec       468.0          LwQ       144.0      270.0        882.0
# 1          ALQ       923.0          Unf         0.0      406.0       1329.0
# 2          GLQ       791.0          Unf         0.0      137.0        928.0
# 3          GLQ       602.0          Unf         0.0      324.0        926.0
# 4          ALQ       263.0          Unf         0.0     1017.0       1280.0
#
#   Heating HeatingQC CentralAir Electrical  1stFlrSF  2ndFlrSF  LowQualFinSF  \
# 0    GasA        TA          Y      SBrkr       896         0             0
# 1    GasA        TA          Y      SBrkr      1329         0             0
# 2    GasA        Gd          Y      SBrkr       928       701             0
# 3    GasA        Ex          Y      SBrkr       926       678             0
# 4    GasA        Ex          Y      SBrkr      1280         0             0
#
#    GrLivArea  BsmtFullBath  BsmtHalfBath  FullBath  HalfBath  BedroomAbvGr  \
# 0        896           0.0           0.0         1         0             2
# 1       1329           0.0           0.0         1         1             3
# 2       1629           0.0           0.0         2         1             3
# 3       1604           0.0           0.0         2         1             3
# 4       1280           0.0           0.0         2         0             2
#
#    KitchenAbvGr KitchenQual  TotRmsAbvGrd Functional  Fireplaces FireplaceQu  \
# 0             1          TA             5        Typ           0     Missing
# 1             1          Gd             6        Typ           0     Missing
# 2             1          TA             6        Typ           1          TA
# 3             1          Gd             7        Typ           1          Gd
# 4             1          Gd             5        Typ           0     Missing
#
#   GarageType  GarageYrBlt GarageFinish  GarageCars  GarageArea GarageQual  \
# 0     Attchd         49.0          Unf         1.0       730.0         TA
# 1     Attchd         52.0          Unf         1.0       312.0         TA
# 2     Attchd         13.0          Fin         2.0       482.0         TA
# 3     Attchd         12.0          Fin         2.0       470.0         TA
# 4     Attchd         18.0          RFn         2.0       506.0         TA
#
#   GarageCond PavedDrive  WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  \
# 0         TA          Y         140            0              0          0
# 1         TA          Y         393           36              0          0
# 2         TA          Y         212           34              0          0
# 3         TA          Y         360           36              0          0
# 4         TA          Y           0           82              0          0
#
#    ScreenPorch  PoolArea   PoolQC    Fence MiscFeature  MiscVal  MoSold  \
# 0          120         0  Missing    MnPrv     Missing        0       6
# 1            0         0  Missing  Missing        Gar2    12500       6
# 2            0         0  Missing    MnPrv     Missing        0       3
# 3            0         0  Missing  Missing     Missing        0       6
# 4          144         0  Missing  Missing     Missing        0       1
#
#    YrSold SaleType SaleCondition  SalePrice
# 0    2010       WD        Normal     208500
# 1    2010       WD        Normal     181500
# 2    2010       WD        Normal     223500
# 3    2010       WD        Normal     140000
# 4    2010       WD        Normal     250000

# %%
dataset_train[log_transform].head()
# Out:
#    LotFrontage  LotArea  1stFlrSF  GrLivArea  SalePrice
# 0         80.0    11622       896        896     208500
# 1         81.0    14267      1329       1329     181500
# 2         74.0    13830       928       1629     223500
# 3         78.0     9978       926       1604     140000
# 4         43.0     5005      1280       1280     250000

# %%
dataset_test[log_transform].head()
# Out:
#    LotFrontage  LotArea  1stFlrSF  GrLivArea  SalePrice
# 0         80.0    11622       896        896     208500
# 1         81.0    14267      1329       1329     181500
# 2         74.0    13830       928       1629     223500
# 3         78.0     9978       926       1604     140000
# 4         43.0     5005      1280       1280     250000

# %%
for feature in log_transform:
    dataset_train[feature] = np.log(dataset_train[feature])
    dataset_test[feature] = np.log(dataset_test[feature])

# %%
dataset_train[log_transform]
# Out:
#       LotFrontage   LotArea  1stFlrSF  GrLivArea  SalePrice
# 0        4.382027  9.360655  6.797940   6.797940  12.247694
# 1        4.394449  9.565704  7.192182   7.192182  12.109011
# 2        4.304065  9.534595  6.833032   7.395722  12.317167
# 3        4.356709  9.208138  6.830874   7.380256  11.849398
# 4        3.761200  8.518193  7.154615   7.154615  12.429216
# ...           ...       ...       ...        ...        ...
# 1454     3.044522  7.568379  6.302619   6.995766  12.128111
# 1455     3.044522  7.546446  6.302619   6.995766  12.072541
# 1456     5.075174  9.903488  7.109879   7.109879  12.254863
# 1457     4.127134  9.253496  6.877296   6.877296  12.493130
# 1458     4.304065  9.172327  6.903747   7.600902  11.864462
#
# [1459 rows x 5 columns]

# %%
dataset_test[log_transform]
# Out:
#       LotFrontage   LotArea  1stFlrSF  GrLivArea  SalePrice
# 0        4.382027  9.360655  6.797940   6.797940  12.247694
# 1        4.394449  9.565704  7.192182   7.192182  12.109011
# 2        4.304065  9.534595  6.833032   7.395722  12.317167
# 3        4.356709  9.208138  6.830874   7.380256  11.849398
# 4        3.761200  8.518193  7.154615   7.154615  12.429216
# ...           ...       ...       ...        ...        ...
# 1454     3.044522  7.568379  6.302619   6.995766  12.128111
# 1455     3.044522  7.546446  6.302619   6.995766  12.072541
# 1456     5.075174  9.903488  7.109879   7.109879  12.254863
# 1457     4.127134  9.253496  6.877296   6.877296  12.493130
# 1458     4.304065  9.172327  6.903747   7.600902  11.864462
#
# [1459 rows x 5 columns]

# %%
# handling Rare categorical feature from dataset_train

categorical_var_for_train = [feature for feature in dataset_train.columns if dataset_train[feature].dtypes == "O"]
len(categorical_var_for_train)
# Out:
# 43

# %%
for feature in categorical_var_for_train:
    temp = dataset_train.groupby(feature)["SalePrice"].count()/len(dataset_train)
    temp_list = temp[temp>0.01].index
    dataset_train[feature] = np.where(dataset_train[feature].isin(temp_list), dataset_train[feature], "Rare Variable")

# %%
dataset_train[categorical_var_for_train].head(50)
# Out:
#          MSZoning Street    Alley LotShape LandContour Utilities LotConfig  \
# 0   Rare Variable   Pave  Missing      Reg         Lvl    AllPub    Inside
# 1              RL   Pave  Missing      IR1         Lvl    AllPub    Corner
# 2              RL   Pave  Missing      IR1         Lvl    AllPub    Inside
# 3              RL   Pave  Missing      IR1         Lvl    AllPub    Inside
# 4              RL   Pave  Missing      IR1         HLS    AllPub    Inside
# 5              RL   Pave  Missing      IR1         Lvl    AllPub    Corner
# 6              RL   Pave  Missing      IR1         Lvl    AllPub    Inside
# 7              RL   Pave  Missing      IR1         Lvl    AllPub    Inside
# 8              RL   Pave  Missing      Reg         Lvl    AllPub    Inside
# 9              RL   Pave  Missing      Reg         Lvl    AllPub    Corner
# 10  Rare Variable   Pave  Missing      IR1         Lvl    AllPub       FR2
# 11             RM   Pave  Missing      Reg         Lvl    AllPub    Inside
# 12             RM   Pave  Missing      Reg         Lvl    AllPub    Inside
# 13             RL   Pave  Missing      Reg         Lvl    AllPub       FR2
# 14             RL   Pave  Missing      Reg         Lvl    AllPub       FR2
# 15             RL   Pave  Missing      IR1         Lvl    AllPub    Inside
# 16             RL   Pave  Missing      IR1         Lvl    AllPub    Corner
# 17             RL   Pave  Missing      Reg         Lvl    AllPub    Inside
# 18             RL   Pave  Missing      IR1         Lvl    AllPub    Inside
# 19             RL   Pave  Missing      Reg         HLS    AllPub    Inside
# 20             RL   Pave  Missing      Reg         Lvl    AllPub    Corner
# 21             RL   Pave  Missing      IR1         Lvl    AllPub    Inside
# 22             RL   Pave  Missing      IR1         Lvl    AllPub    Corner
# 23             RL   Pave  Missing      Reg         Lvl    AllPub    Inside
# 24             RL   Pave  Missing      IR1         Lvl    AllPub    Inside
# 25             RL   Pave  Missing      IR1         Lvl    AllPub    Inside
# 26             RL   Pave  Missing      IR2         Lvl    AllPub   CulDSac
# 27             RL   Pave  Missing      Reg         Lvl    AllPub    Inside
# 28             FV   Pave  Missing      Reg         Lvl    AllPub    Inside
# 29             FV   Pave  Missing      Reg         Lvl    AllPub    Corner
# 30             RL   Pave  Missing      Reg         Lvl    AllPub    Inside
# 31  Rare Variable   Pave  Missing      Reg         Lvl    AllPub    Corner
# 32             RL   Pave  Missing      IR1         Lvl    AllPub   CulDSac
# 33             RL   Pave  Missing      IR1         Lvl    AllPub    Inside
# 34             RL   Pave  Missing      Reg         Lvl    AllPub    Inside
# 35             FV   Pave  Missing      IR1         Lvl    AllPub   CulDSac
# 36             FV   Pave     Pave      Reg         Lvl    AllPub    Inside
# 37             FV   Pave     Pave      Reg         Lvl    AllPub    Inside
# 38             FV   Pave     Pave      Reg         Lvl    AllPub    Inside
# 39             FV   Pave     Pave      Reg         Lvl    AllPub    Inside
# 40             FV   Pave  Missing      Reg         Lvl    AllPub    Corner
# 41             FV   Pave  Missing      IR1         Lvl    AllPub       FR2
# 42             FV   Pave     Pave      IR1         Lvl    AllPub    Inside
# 43             FV   Pave  Missing      IR1         Lvl    AllPub    Inside
# 44             FV   Pave  Missing      Reg         Lvl    AllPub    Inside
# 45             RL   Pave  Missing      IR1         Lvl    AllPub    Inside
# 46             RL   Pave  Missing      Reg         Lvl    AllPub    Inside
# 47             RL   Pave  Missing      IR1         Lvl    AllPub    Inside
# 48             RL   Pave  Missing      Reg         Lvl    AllPub    Inside
# 49             RL   Pave  Missing      Reg         Lvl    AllPub    Inside
#
#    LandSlope   Neighborhood     Condition1 Condition2 BldgType HouseStyle  \
# 0        Gtl          NAmes          Feedr       Norm     1Fam     1Story
# 1        Gtl          NAmes           Norm       Norm     1Fam     1Story
# 2        Gtl        Gilbert           Norm       Norm     1Fam     2Story
# 3        Gtl        Gilbert           Norm       Norm     1Fam     2Story
# 4        Gtl        StoneBr           Norm       Norm   TwnhsE     1Story
# 5        Gtl        Gilbert           Norm       Norm     1Fam     2Story
# 6        Gtl        Gilbert           Norm       Norm     1Fam     1Story
# 7        Gtl        Gilbert           Norm       Norm     1Fam     2Story
# 8        Gtl        Gilbert           Norm       Norm     1Fam     1Story
# 9        Gtl          NAmes           Norm       Norm     1Fam     1Story
# 10       Gtl          NAmes           Norm       Norm   TwnhsE     1Story
# 11       Gtl  Rare Variable           Norm       Norm    Twnhs     2Story
# 12       Gtl  Rare Variable           Norm       Norm    Twnhs     2Story
# 13       Gtl  Rare Variable           Norm       Norm    Twnhs     2Story
# 14       Gtl  Rare Variable           Norm       Norm    Twnhs     1Story
# 15       Gtl        NridgHt           Norm       Norm     1Fam     2Story
# 16       Gtl        NridgHt           Norm       Norm     1Fam     1Story
# 17       Gtl        NridgHt           PosN       Norm     1Fam     1Story
# 18       Gtl        NridgHt           Norm       Norm     1Fam     1Story
# 19       Mod        NridgHt           Norm       Norm     1Fam     1Story
# 20       Gtl        NridgHt           Norm       Norm     1Fam     2Story
# 21       Gtl        NridgHt           Norm       Norm   TwnhsE     1Story
# 22       Gtl        Gilbert           Norm       Norm     1Fam     1Story
# 23       Gtl  Rare Variable           Norm       Norm   TwnhsE     1Story
# 24       Gtl        Gilbert           Norm       Norm     1Fam       SLvl
# 25       Gtl        Gilbert           Norm       Norm     1Fam     2Story
# 26       Gtl        NoRidge           Norm       Norm     1Fam     2Story
# 27       Gtl        Somerst           Norm       Norm     1Fam     1Story
# 28       Gtl        Somerst           Norm       Norm     1Fam     1Story
# 29       Gtl        Somerst           Norm       Norm     1Fam     1Story
# 30       Gtl        SawyerW           Norm       Norm     1Fam     2Story
# 31       Gtl        SawyerW          Feedr       Norm     1Fam     1Story
# 32       Gtl         Sawyer  Rare Variable       Norm     1Fam     1Story
# 33       Gtl        NoRidge           Norm       Norm     1Fam     2Story
# 34       Gtl        NoRidge           Norm       Norm     1Fam     2Story
# 35       Gtl        Somerst           Norm       Norm   TwnhsE     1Story
# 36       Gtl        Somerst           Norm       Norm   TwnhsE     2Story
# 37       Gtl        Somerst           Norm       Norm   TwnhsE     2Story
# 38       Gtl        Somerst           Norm       Norm    Twnhs     2Story
# 39       Gtl        Somerst           Norm       Norm    Twnhs     2Story
# 40       Gtl        Somerst           Norm       Norm   TwnhsE     2Story
# 41       Gtl        Somerst           Norm       Norm   TwnhsE     2Story
# 42       Gtl        Somerst           Norm       Norm     1Fam     1Story
# 43       Gtl        Somerst           Norm       Norm     1Fam     2Story
# 44       Gtl        Somerst           Norm       Norm     1Fam     1Story
# 45       Gtl         NWAmes           Norm       Norm     1Fam     1Story
# 46       Gtl         NWAmes           Norm       Norm     1Fam     2Story
# 47       Gtl         NWAmes           Norm       Norm     1Fam     1.5Fin
# 48       Gtl         NWAmes           Norm       Norm     1Fam     2Story
# 49       Gtl          NAmes           Norm       Norm     1Fam     1Story
#
#    RoofStyle RoofMatl Exterior1st    Exterior2nd     MasVnrType ExterQual  \
# 0      Gable  CompShg     VinylSd        VinylSd           None        TA
# 1        Hip  CompShg     Wd Sdng        Wd Sdng        BrkFace        TA
# 2      Gable  CompShg     VinylSd        VinylSd           None        TA
# 3      Gable  CompShg     VinylSd        VinylSd        BrkFace        TA
# 4      Gable  CompShg     HdBoard        HdBoard           None        Gd
# 5      Gable  CompShg     HdBoard        HdBoard           None        TA
# 6      Gable  CompShg     HdBoard        HdBoard           None        TA
# 7      Gable  CompShg     VinylSd        VinylSd           None        TA
# 8      Gable  CompShg     HdBoard        HdBoard           None        TA
# 9      Gable  CompShg     Plywood        Plywood           None        TA
# 10     Gable  CompShg     MetalSd        MetalSd           None        Gd
# 11     Gable  CompShg     HdBoard        HdBoard        BrkFace        TA
# 12     Gable  CompShg     HdBoard        HdBoard        BrkFace        TA
# 13     Gable  CompShg     Plywood        Brk Cmn           None        TA
# 14     Gable  CompShg     Plywood        Brk Cmn           None        TA
# 15     Gable  CompShg     VinylSd        VinylSd          Stone        Ex
# 16     Gable  CompShg     VinylSd        VinylSd          Stone        Gd
# 17       Hip  CompShg     VinylSd        VinylSd        BrkFace        Gd
# 18       Hip  CompShg     CemntBd        CmentBd        BrkFace        Gd
# 19       Hip  CompShg     VinylSd        VinylSd        BrkFace        Ex
# 20     Gable  CompShg     VinylSd        VinylSd        BrkFace        Gd
# 21     Gable  CompShg     VinylSd        VinylSd          Stone        Gd
# 22     Gable  CompShg     VinylSd        VinylSd           None        Gd
# 23     Gable  CompShg     VinylSd        VinylSd        BrkFace        Gd
# 24     Gable  CompShg     VinylSd        VinylSd           None        Gd
# 25     Gable  CompShg     VinylSd        VinylSd           None        Gd
# 26       Hip  CompShg     VinylSd        VinylSd        BrkFace        Gd
# 27     Gable  CompShg     VinylSd        VinylSd        BrkFace        Gd
# 28       Hip  CompShg     VinylSd        VinylSd           None        Gd
# 29     Gable  CompShg     VinylSd        VinylSd           None        Gd
# 30     Gable  CompShg     VinylSd        VinylSd        BrkFace        Gd
# 31     Gable  CompShg     Wd Sdng        Wd Sdng           None        TA
# 32       Hip  CompShg     Plywood        Plywood  Rare Variable        TA
# 33     Gable  CompShg     HdBoard  Rare Variable        BrkFace        Gd
# 34     Gable  CompShg     HdBoard        HdBoard        BrkFace        Gd
# 35     Gable  CompShg     MetalSd        MetalSd           None        Gd
# 36     Gable  CompShg     VinylSd        VinylSd           None        Gd
# 37     Gable  CompShg     MetalSd        MetalSd        BrkFace        Gd
# 38     Gable  CompShg     MetalSd        MetalSd           None        Gd
# 39     Gable  CompShg     VinylSd        VinylSd        BrkFace        Gd
# 40     Gable  CompShg     MetalSd        MetalSd        BrkFace        Gd
# 41     Gable  CompShg     VinylSd        VinylSd           None        Gd
# 42     Gable  CompShg     CemntBd        CmentBd           None        Gd
# 43     Gable  CompShg     VinylSd        VinylSd           None        Gd
# 44     Gable  CompShg     VinylSd        VinylSd           None        Gd
# 45       Hip  CompShg     HdBoard        HdBoard        BrkFace        TA
# 46     Gable  CompShg     MetalSd        MetalSd           None        TA
# 47     Gable  CompShg     MetalSd        MetalSd           None        TA
# 48     Gable  CompShg     MetalSd        MetalSd           None        TA
# 49       Hip  CompShg     VinylSd        VinylSd        BrkFace        TA
#
#    ExterCond Foundation BsmtQual       BsmtCond BsmtExposure BsmtFinType1  \
# 0         TA     CBlock       TA             TA           No          Rec
# 1         TA     CBlock       TA             TA           No          ALQ
# 2         TA      PConc       Gd             TA           No          GLQ
# 3         TA      PConc       TA             TA           No          GLQ
# 4         TA      PConc       Gd             TA           No          ALQ
# 5         TA      PConc       Gd             TA           No          Unf
# 6         Gd      PConc       Gd             TA           No          ALQ
# 7         TA      PConc       Gd             TA           No          Unf
# 8         TA      PConc       Gd             TA           Gd          GLQ
# 9         TA     CBlock       TA             TA           No          ALQ
# 10        TA      PConc       Gd             TA           No          GLQ
# 11        TA     CBlock       TA             TA           No          Rec
# 12        TA     CBlock       TA             TA           No          Rec
# 13        TA     CBlock       TA             TA           No          ALQ
# 14        TA     CBlock       Gd             TA           No          Unf
# 15        TA      PConc       Ex             TA           No          Unf
# 16        TA      PConc       Gd             TA           No          Unf
# 17        TA      PConc       Ex             TA           No          GLQ
# 18        TA      PConc       Ex             TA           No          GLQ
# 19        TA      PConc       Ex             TA           Gd          GLQ
# 20        TA      PConc       Gd             TA           Gd          GLQ
# 21        TA      PConc       Gd             TA           Mn          GLQ
# 22        TA      PConc       Gd             TA           No          Unf
# 23        TA      PConc       Gd             TA           Av          GLQ
# 24        TA      PConc       Gd             TA           No          GLQ
# 25        TA      PConc       Gd             TA           No          Unf
# 26        TA      PConc       Ex             TA           No          Unf
# 27        TA      PConc       Gd             TA      Missing          Unf
# 28        TA      PConc       Gd             TA           No          Unf
# 29        TA      PConc       Ex             TA           No          GLQ
# 30        TA      PConc       Gd             TA           Av          Unf
# 31        Fa     BrkTil       TA             TA           No          Unf
# 32        Gd     CBlock       TA             TA           Gd          BLQ
# 33        TA      PConc       Gd             TA           No          LwQ
# 34        TA      PConc       Gd             TA           No          GLQ
# 35        TA      PConc       Ex             TA           Av          GLQ
# 36        TA      PConc       Gd             TA           No          Unf
# 37        TA      PConc       Gd             TA           Av          GLQ
# 38        TA      PConc       Gd             TA           No          GLQ
# 39        TA      PConc       Gd             TA           No          GLQ
# 40        TA      PConc       Gd             TA           No          GLQ
# 41        TA      PConc       Gd             TA           No          GLQ
# 42        TA      PConc       Ex  Rare Variable           No          GLQ
# 43        TA      PConc       Gd             TA           No          GLQ
# 44        TA      PConc       Gd             TA           No          GLQ
# 45        TA     CBlock       TA             TA           No          GLQ
# 46        TA      PConc       Gd             TA           Mn          GLQ
# 47        TA      PConc       Gd             TA           Mn          ALQ
# 48        TA     CBlock       TA             TA           No          ALQ
# 49        TA     CBlock       TA             TA           No          Rec
#
#    BsmtFinType2 Heating HeatingQC CentralAir Electrical KitchenQual  \
# 0           LwQ    GasA        TA          Y      SBrkr          TA
# 1           Unf    GasA        TA          Y      SBrkr          Gd
# 2           Unf    GasA        Gd          Y      SBrkr          TA
# 3           Unf    GasA        Ex          Y      SBrkr          Gd
# 4           Unf    GasA        Ex          Y      SBrkr          Gd
# 5           Unf    GasA        Gd          Y      SBrkr          TA
# 6           Unf    GasA        Ex          Y      SBrkr          TA
# 7           Unf    GasA        Gd          Y      SBrkr          TA
# 8           Unf    GasA        Gd          Y      SBrkr          Gd
# 9           Rec    GasA        TA          Y      SBrkr          TA
# 10          BLQ    GasA        Ex          Y      SBrkr          Gd
# 11          Unf    GasA        TA          Y      SBrkr          TA
# 12          Unf    GasA        TA          Y      SBrkr          TA
# 13          Unf    GasA        TA          Y      SBrkr          Gd
# 14          Unf    GasA        Ex          Y      SBrkr          TA
# 15          Unf    GasA        Ex          Y      SBrkr          Ex
# 16          Unf    GasA        Ex          Y      SBrkr          Gd
# 17          Unf    GasA        Ex          Y      SBrkr          Ex
# 18          Unf    GasA        Ex          Y      SBrkr          Ex
# 19          Unf    GasA        Ex          Y      SBrkr          Ex
# 20          Unf    GasA        Ex          Y      SBrkr          Gd
# 21          Unf    GasA        Ex          Y      SBrkr          Gd
# 22          Unf    GasA        Ex          Y      SBrkr          Gd
# 23          Unf    GasA        Ex          Y      SBrkr          Gd
# 24          Unf    GasA        Ex          Y      SBrkr          Gd
# 25          Unf    GasA        Ex          Y      SBrkr          Gd
# 26          Unf    GasA        Ex          Y      SBrkr          Gd
# 27          Unf    GasA        Ex          Y      SBrkr          Gd
# 28          Unf    GasA        Ex          Y      SBrkr          Gd
# 29          Unf    GasA        Ex          Y      SBrkr          Gd
# 30          Unf    GasA        Ex          Y      SBrkr          Gd
# 31          Unf    GasA        TA          N      FuseA          TA
# 32          GLQ    GasA        Ex          Y      SBrkr          TA
# 33          GLQ    GasA        Ex          Y      SBrkr          Gd
# 34          Unf    GasA        Ex          Y      SBrkr          Gd
# 35          Unf    GasA        Ex          Y      SBrkr          Gd
# 36          Unf    GasA        Ex          Y      SBrkr          Gd
# 37          Unf    GasA        Ex          Y      SBrkr          Gd
# 38          ALQ    GasA        Ex          Y      SBrkr          Gd
# 39          Unf    GasA        Ex          Y      SBrkr          Gd
# 40          Unf    GasA        Ex          Y      SBrkr          Gd
# 41          Unf    GasA        Ex          Y      SBrkr          Gd
# 42          Unf    GasA        Ex          Y      SBrkr          Gd
# 43          Unf    GasA        Ex          Y      SBrkr          Gd
# 44          Unf    GasA        Ex          Y      SBrkr          Gd
# 45          Unf    GasA        Gd          Y      SBrkr          TA
# 46          Unf    GasA        Ex          Y      SBrkr          Gd
# 47          LwQ    GasA        TA          Y      SBrkr          TA
# 48          Unf    GasA        TA          Y      SBrkr          TA
# 49          Unf    GasA        TA          Y      SBrkr          TA
#
#    Functional FireplaceQu GarageType GarageFinish GarageQual GarageCond  \
# 0         Typ     Missing     Attchd          Unf         TA         TA
# 1         Typ     Missing     Attchd          Unf         TA         TA
# 2         Typ          TA     Attchd          Fin         TA         TA
# 3         Typ          Gd     Attchd          Fin         TA         TA
# 4         Typ     Missing     Attchd          RFn         TA         TA
# 5         Typ          TA     Attchd          Fin         TA         TA
# 6         Typ     Missing     Attchd          Fin         TA         TA
# 7         Typ          Gd     Attchd          Fin         TA         TA
# 8         Typ          Po     Attchd          Unf         TA         TA
# 9         Typ     Missing     Attchd          Fin         TA         TA
# 10        Typ          Fa     Attchd          Fin         TA         TA
# 11        Typ     Missing     Detchd          Unf         TA         TA
# 12        Typ     Missing     Detchd          Unf         TA         TA
# 13        Typ          TA     Attchd          Unf         TA         TA
# 14        Typ     Missing     Attchd          Unf         TA         TA
# 15        Typ          Gd     Attchd          Fin         TA         TA
# 16        Typ     Missing     Attchd          RFn         TA         TA
# 17        Typ          Gd     Attchd          Fin         TA         TA
# 18        Typ          Gd     Attchd          RFn         TA         TA
# 19        Typ          Gd     Attchd          Fin         TA         TA
# 20        Typ          Ex     Attchd          Fin         TA         TA
# 21        Typ          Gd     Attchd          RFn         TA         TA
# 22        Typ     Missing     Attchd          Fin         TA         TA
# 23        Typ     Missing     Attchd          Fin         TA         TA
# 24        Typ          Gd    BuiltIn          Fin         TA         TA
# 25        Typ          Gd    BuiltIn          Fin         TA         TA
# 26        Typ          TA     Attchd          Fin         TA         TA
# 27        Typ          Gd     Attchd          RFn         TA         TA
# 28        Typ     Missing     Attchd          RFn         TA         TA
# 29        Typ          Gd     Attchd          Fin         TA         TA
# 30        Typ     Missing     Attchd          RFn         TA         TA
# 31        Typ     Missing     Detchd          Unf         TA         TA
# 32        Typ          Fa     Attchd          Fin         TA         TA
# 33        Typ          TA     Attchd          RFn         TA         TA
# 34        Typ          TA     Attchd          RFn         TA         TA
# 35        Typ          Gd     Attchd          Fin         TA         TA
# 36        Typ     Missing     Attchd          RFn         TA         TA
# 37        Typ     Missing     Detchd          RFn         TA         TA
# 38        Typ     Missing     Detchd          RFn         TA         TA
# 39        Typ     Missing     Detchd          RFn         TA         TA
# 40        Typ     Missing     Detchd          Unf         TA         TA
# 41        Typ     Missing     Attchd          RFn         TA         TA
# 42        Typ          Gd     Attchd          RFn         TA         TA
# 43        Typ          TA     Attchd          RFn         TA         TA
# 44        Typ          Gd     Attchd          RFn         TA         TA
# 45        Typ     Missing     Attchd          RFn         TA         TA
# 46        Typ          TA     Attchd          Unf         TA         TA
# 47        Typ          TA     Attchd          RFn         TA         TA
# 48        Typ     Missing     Attchd          RFn         TA         TA
# 49        Typ     Missing     Attchd          RFn         TA         TA
#
#    PavedDrive   PoolQC    Fence    MiscFeature SaleType SaleCondition
# 0           Y  Missing    MnPrv        Missing       WD        Normal
# 1           Y  Missing  Missing  Rare Variable       WD        Normal
# 2           Y  Missing    MnPrv        Missing       WD        Normal
# 3           Y  Missing  Missing        Missing       WD        Normal
# 4           Y  Missing  Missing        Missing       WD        Normal
# 5           Y  Missing  Missing        Missing       WD        Normal
# 6           Y  Missing    GdPrv           Shed       WD        Normal
# 7           Y  Missing  Missing        Missing       WD        Normal
# 8           Y  Missing  Missing        Missing       WD        Normal
# 9           Y  Missing    MnPrv        Missing       WD        Normal
# 10          Y  Missing  Missing        Missing       WD        Normal
# 11          Y  Missing  Missing        Missing      COD        Normal
# 12          Y  Missing  Missing        Missing       WD        Normal
# 13          Y  Missing  Missing        Missing       WD        Normal
# 14          Y  Missing  Missing        Missing       WD        Normal
# 15          Y  Missing  Missing        Missing      New       Partial
# 16          Y  Missing  Missing        Missing      New       Partial
# 17          Y  Missing  Missing        Missing       WD        Normal
# 18          Y  Missing  Missing        Missing       WD        Normal
# 19          Y  Missing  Missing        Missing       WD        Normal
# 20          Y  Missing  Missing        Missing       WD        Normal
# 21          Y  Missing  Missing        Missing       WD        Normal
# 22          Y  Missing  Missing        Missing       WD        Normal
# 23          Y  Missing  Missing        Missing       WD        Normal
# 24          Y  Missing  Missing        Missing       WD        Normal
# 25          Y  Missing  Missing        Missing       WD        Normal
# 26          Y  Missing  Missing        Missing       WD        Normal
# 27          Y  Missing  Missing        Missing       WD        Normal
# 28          Y  Missing  Missing        Missing      New       Partial
# 29          Y  Missing  Missing        Missing       WD        Normal
# 30          Y  Missing  Missing        Missing       WD        Normal
# 31          Y  Missing  Missing        Missing       WD        Normal
# 32          Y  Missing    GdPrv        Missing       WD       Abnorml
# 33          Y  Missing  Missing        Missing       WD        Normal
# 34          Y  Missing  Missing        Missing       WD        Normal
# 35          Y  Missing  Missing        Missing       WD        Normal
# 36          Y  Missing  Missing        Missing       WD        Normal
# 37          Y  Missing  Missing        Missing    ConLD        Normal
# 38          Y  Missing  Missing        Missing       WD        Normal
# 39          Y  Missing  Missing        Missing       WD        Normal
# 40          Y  Missing  Missing        Missing       WD        Normal
# 41          Y  Missing  Missing        Missing       WD        Normal
# 42          Y  Missing  Missing        Missing      New       Partial
# 43          Y  Missing  Missing        Missing       WD        Normal
# 44          Y  Missing  Missing        Missing       WD        Normal
# 45          Y  Missing  Missing        Missing       WD        Normal
# 46          Y  Missing  Missing        Missing       WD        Normal
# 47          Y  Missing  Missing        Missing       WD        Normal
# 48          Y  Missing     GdWo        Missing       WD        Normal
# 49          Y  Missing  Missing        Missing       WD        Normal

# %%
# handling Rare categorical feature from dataset_test

categorical_var_for_test = [feature for feature in dataset_test.columns if dataset_test[feature].dtypes == "O"]
len(categorical_var_for_test)
# Out:
# 43

# %%
for feature in categorical_var_for_test:
    temp_var = dataset_test.groupby(feature)["SalePrice"].count()/len(dataset_test)
    temp_var_list = temp_var[temp_var>0.01].index
    dataset_test[feature] = np.where(dataset_test[feature].isin(temp_var_list), dataset_test[feature], "Rare Variable")

# %%
dataset_test[categorical_feature_for_test].head(20)
# Out:
#          MSZoning    Alley Utilities MasVnrType BsmtQual BsmtCond  \
# 0   Rare Variable  Missing    AllPub       None       TA       TA
# 1              RL  Missing    AllPub    BrkFace       TA       TA
# 2              RL  Missing    AllPub       None       Gd       TA
# 3              RL  Missing    AllPub    BrkFace       TA       TA
# 4              RL  Missing    AllPub       None       Gd       TA
# 5              RL  Missing    AllPub       None       Gd       TA
# 6              RL  Missing    AllPub       None       Gd       TA
# 7              RL  Missing    AllPub       None       Gd       TA
# 8              RL  Missing    AllPub       None       Gd       TA
# 9              RL  Missing    AllPub       None       TA       TA
# 10  Rare Variable  Missing    AllPub       None       Gd       TA
# 11             RM  Missing    AllPub    BrkFace       TA       TA
# 12             RM  Missing    AllPub    BrkFace       TA       TA
# 13             RL  Missing    AllPub       None       TA       TA
# 14             RL  Missing    AllPub       None       Gd       TA
# 15             RL  Missing    AllPub      Stone       Ex       TA
# 16             RL  Missing    AllPub      Stone       Gd       TA
# 17             RL  Missing    AllPub    BrkFace       Ex       TA
# 18             RL  Missing    AllPub    BrkFace       Ex       TA
# 19             RL  Missing    AllPub    BrkFace       Ex       TA
#
#    BsmtExposure BsmtFinType1 BsmtFinType2 Functional FireplaceQu GarageType  \
# 0            No          Rec          LwQ        Typ     Missing     Attchd
# 1            No          ALQ          Unf        Typ     Missing     Attchd
# 2            No          GLQ          Unf        Typ          TA     Attchd
# 3            No          GLQ          Unf        Typ          Gd     Attchd
# 4            No          ALQ          Unf        Typ     Missing     Attchd
# 5            No          Unf          Unf        Typ          TA     Attchd
# 6            No          ALQ          Unf        Typ     Missing     Attchd
# 7            No          Unf          Unf        Typ          Gd     Attchd
# 8            Gd          GLQ          Unf        Typ          Po     Attchd
# 9            No          ALQ          Rec        Typ     Missing     Attchd
# 10           No          GLQ          BLQ        Typ          Fa     Attchd
# 11           No          Rec          Unf        Typ     Missing     Detchd
# 12           No          Rec          Unf        Typ     Missing     Detchd
# 13           No          ALQ          Unf        Typ          TA     Attchd
# 14           No          Unf          Unf        Typ     Missing     Attchd
# 15           No          Unf          Unf        Typ          Gd     Attchd
# 16           No          Unf          Unf        Typ     Missing     Attchd
# 17           No          GLQ          Unf        Typ          Gd     Attchd
# 18           No          GLQ          Unf        Typ          Gd     Attchd
# 19           Gd          GLQ          Unf        Typ          Gd     Attchd
#
#    GarageFinish GarageQual GarageCond   PoolQC    Fence    MiscFeature
# 0           Unf         TA         TA  Missing    MnPrv        Missing
# 1           Unf         TA         TA  Missing  Missing  Rare Variable
# 2           Fin         TA         TA  Missing    MnPrv        Missing
# 3           Fin         TA         TA  Missing  Missing        Missing
# 4           RFn         TA         TA  Missing  Missing        Missing
# 5           Fin         TA         TA  Missing  Missing        Missing
# 6           Fin         TA         TA  Missing    GdPrv           Shed
# 7           Fin         TA         TA  Missing  Missing        Missing
# 8           Unf         TA         TA  Missing  Missing        Missing
# 9           Fin         TA         TA  Missing    MnPrv        Missing
# 10          Fin         TA         TA  Missing  Missing        Missing
# 11          Unf         TA         TA  Missing  Missing        Missing
# 12          Unf         TA         TA  Missing  Missing        Missing
# 13          Unf         TA         TA  Missing  Missing        Missing
# 14          Unf         TA         TA  Missing  Missing        Missing
# 15          Fin         TA         TA  Missing  Missing        Missing
# 16          RFn         TA         TA  Missing  Missing        Missing
# 17          Fin         TA         TA  Missing  Missing        Missing
# 18          RFn         TA         TA  Missing  Missing        Missing
# 19          Fin         TA         TA  Missing  Missing        Missing

# %%
categorical_var_for_train
# Out:
# ['MSZoning',
#  'Street',
#  'Alley',
#  'LotShape',
#  'LandContour',
#  'Utilities',
#  'LotConfig',
#  'LandSlope',
#  'Neighborhood',
#  'Condition1',
#  'Condition2',
#  'BldgType',
#  'HouseStyle',
#  'RoofStyle',
#  'RoofMatl',
#  'Exterior1st',
#  'Exterior2nd',
#  'MasVnrType',
#  'ExterQual',
#  'ExterCond',
#  'Foundation',
#  'BsmtQual',
#  'BsmtCond',
#  'BsmtExposure',
#  'BsmtFinType1',
#  'BsmtFinType2',
#  'Heating',
#  'HeatingQC',
#  'CentralAir',
#  'Electrical',
#  'KitchenQual',
#  'Functional',
#  'FireplaceQu',
#  'GarageType',
#  'GarageFinish',
#  'GarageQual',
#  'GarageCond',
#  'PavedDrive',
#  'PoolQC',
#  'Fence',
#  'MiscFeature',
#  'SaleType',
#  'SaleCondition']

# %%
# converting the categorical features of dataset_train into numerical features

for feature in categorical_var_for_train:
    labels_ordered = dataset_train.groupby(feature)["SalePrice"].mean().sort_values().index
    labels_ordered = {k:i for i, k in enumerate(labels_ordered, 0)}
    dataset_train[feature] = dataset_train[feature].map(labels_ordered)

# %%
# converting the categorical features of dataset_test into numerical features

for feature in categorical_var_for_test:
    labels_ordered = dataset_test.groupby(feature)["SalePrice"].mean().sort_values().index
    labels_ordered = {k:i for i, k in enumerate(labels_ordered, 0)}
    dataset_test[feature] = dataset_test[feature].map(labels_ordered)

# %%
dataset_train.head(15)
# Out:
#       Id  MSSubClass  MSZoning  LotFrontage   LotArea  Street  Alley  \
# 0   1461          20         4     4.382027  9.360655       0      1
# 1   1462          20         3     4.394449  9.565704       0      1
# 2   1463          60         3     4.304065  9.534595       0      1
# 3   1464          60         3     4.356709  9.208138       0      1
# 4   1465         120         3     3.761200  8.518193       0      1
# 5   1466          60         3     4.317488  9.210340       0      1
# 6   1467          20         3     4.204693  8.984694       0      1
# 7   1468          60         3     4.143135  9.036225       0      1
# 8   1469          20         3     4.442651  9.227787       0      1
# 9   1470          20         3     4.248495  9.035987       0      1
# 10  1471         120         4     3.258097  8.675564       0      1
# 11  1472         160         0     3.044522  7.426549       0      1
# 12  1473         160         0     3.044522  7.426549       0      1
# 13  1474         160         3     3.178054  7.731931       0      1
# 14  1475         120         3     3.178054  7.731931       0      1
#
#     LotShape  LandContour  Utilities  LotConfig  LandSlope  Neighborhood  \
# 0          0            3          1          1          1            16
# 1          1            3          1          2          1            16
# 2          1            3          1          1          1            19
# 3          1            3          1          1          1            19
# 4          1            2          1          1          1            20
# 5          1            3          1          2          1            19
# 6          1            3          1          1          1            19
# 7          1            3          1          1          1            19
# 8          0            3          1          1          1            19
# 9          0            3          1          2          1            16
# 10         1            3          1          0          1            16
# 11         0            3          1          1          1            14
# 12         0            3          1          1          1            14
# 13         0            3          1          0          1            14
# 14         0            3          1          0          1            14
#
#     Condition1  Condition2  BldgType  HouseStyle  OverallQual  OverallCond  \
# 0            3           0         0           3            5            6
# 1            2           0         0           3            6            6
# 2            2           0         0           2            5            5
# 3            2           0         0           2            6            6
# 4            2           0         2           3            8            5
# 5            2           0         0           2            6            5
# 6            2           0         0           3            6            7
# 7            2           0         0           2            6            5
# 8            2           0         0           3            7            5
# 9            2           0         0           3            4            5
# 10           2           0         2           3            7            5
# 11           2           0         1           2            6            5
# 12           2           0         1           2            5            5
# 13           2           0         1           2            6            6
# 14           2           0         1           3            7            6
#
#     YearBuilt  YearRemodAdd  RoofStyle  RoofMatl  Exterior1st  Exterior2nd  \
# 0          49            49          0         0            5            4
# 1          52            52          1         0            6            5
# 2          13            12          0         0            5            4
# 3          12            12          0         0            5            4
# 4          18            18          0         0            9            8
# 5          17            16          0         0            9            8
# 6          18             3          0         0            9            8
# 7          12            12          0         0            5            4
# 8          20            20          0         0            9            8
# 9          40            40          0         0            7            9
# 10         11            11          0         0            8            7
# 11         39            39          0         0            9            8
# 12         39            39          0         0            9            8
# 13         35            35          0         0            7           10
# 14         35            35          0         0            7           10
#
#     MasVnrType  MasVnrArea  ExterQual  ExterCond  Foundation  BsmtQual  \
# 0            2         0.0          3          2           2         4
# 1            1       108.0          3          2           2         4
# 2            2         0.0          3          2           3         2
# 3            1        20.0          3          2           3         4
# 4            2         0.0          0          2           3         2
# 5            2         0.0          3          2           3         2
# 6            2         0.0          3          3           3         2
# 7            2         0.0          3          2           3         2
# 8            2         0.0          3          2           3         2
# 9            2         0.0          3          2           2         4
# 10           2         0.0          0          2           3         2
# 11           1       504.0          3          2           2         4
# 12           1       492.0          3          2           2         4
# 13           2         0.0          3          2           2         4
# 14           2         0.0          3          2           2         2
#
#     BsmtCond  BsmtExposure  BsmtFinType1  BsmtFinSF1  BsmtFinType2  \
# 0          2             0             4       468.0             5
# 1          2             0             5       923.0             4
# 2          2             0             2       791.0             4
# 3          2             0             2       602.0             4
# 4          2             0             5       263.0             4
# 5          2             0             3         0.0             4
# 6          2             0             5       935.0             4
# 7          2             0             3         0.0             4
# 8          2             3             2       637.0             4
# 9          2             0             5       804.0             1
# 10         2             0             2      1051.0             6
# 11         2             0             4       156.0             4
# 12         2             0             4       300.0             4
# 13         2             0             5       514.0             4
# 14         2             0             3         0.0             4
#
#     BsmtFinSF2  BsmtUnfSF  TotalBsmtSF  Heating  HeatingQC  CentralAir  \
# 0        144.0      270.0        882.0        1          1           1
# 1          0.0      406.0       1329.0        1          1           1
# 2          0.0      137.0        928.0        1          4           1
# 3          0.0      324.0        926.0        1          3           1
# 4          0.0     1017.0       1280.0        1          3           1
# 5          0.0      763.0        763.0        1          4           1
# 6          0.0      233.0       1168.0        1          3           1
# 7          0.0      789.0        789.0        1          4           1
# 8          0.0      663.0       1300.0        1          4           1
# 9         78.0        0.0        882.0        1          1           1
# 10         0.0      354.0       1405.0        1          3           1
# 11         0.0      327.0        483.0        1          1           1
# 12         0.0      225.0        525.0        1          1           1
# 13         0.0      341.0        855.0        1          1           1
# 14         0.0      836.0        836.0        1          3           1
#
#     Electrical  1stFlrSF  2ndFlrSF  LowQualFinSF  GrLivArea  BsmtFullBath  \
# 0            2  6.797940         0             0   6.797940           0.0
# 1            2  7.192182         0             0   7.192182           0.0
# 2            2  6.833032       701             0   7.395722           0.0
# 3            2  6.830874       678             0   7.380256           0.0
# 4            2  7.154615         0             0   7.154615           0.0
# 5            2  6.637258       892             0   7.411556           0.0
# 6            2  7.079184         0             0   7.079184           1.0
# 7            2  6.670766       676             0   7.289611           0.0
# 8            2  7.201171         0             0   7.201171           1.0
# 9            2  6.782192         0             0   6.782192           1.0
# 10           2  7.198184         0             0   7.198184           1.0
# 11           2  6.180017       504             0   6.894670           0.0
# 12           2  6.263398       567             0   6.995766           0.0
# 13           2  6.751101       601             0   7.283448           0.0
# 14           2  6.728629         0             0   6.728629           0.0
#
#     BsmtHalfBath  FullBath  HalfBath  BedroomAbvGr  KitchenAbvGr  KitchenQual  \
# 0            0.0         1         0             2             1            1
# 1            0.0         1         1             3             1            2
# 2            0.0         2         1             3             1            1
# 3            0.0         2         1             3             1            2
# 4            0.0         2         0             2             1            2
# 5            0.0         2         1             3             1            1
# 6            0.0         2         0             3             1            1
# 7            0.0         2         1             3             1            1
# 8            0.0         1         1             2             1            2
# 9            0.0         1         0             2             1            1
# 10           0.0         2         0             2             1            2
# 11           0.0         1         1             2             1            1
# 12           0.0         1         1             3             1            1
# 13           0.0         2         1             3             1            2
# 14           0.0         1         0             2             1            1
#
#     TotRmsAbvGrd  Functional  Fireplaces  FireplaceQu  GarageType  \
# 0              5           3           0            1           3
# 1              6           3           0            1           3
# 2              6           3           1            5           3
# 3              7           3           1            2           3
# 4              5           3           0            1           3
# 5              7           3           1            5           3
# 6              6           3           0            1           3
# 7              7           3           1            2           3
# 8              5           3           1            3           3
# 9              4           3           0            1           3
# 10             5           3           1            0           3
# 11             5           3           0            1           1
# 12             6           3           0            1           1
# 13             6           3           1            5           3
# 14             4           3           0            1           3
#
#     GarageYrBlt  GarageFinish  GarageCars  GarageArea  GarageQual  GarageCond  \
# 0          49.0             2         1.0       730.0           2           3
# 1          52.0             2         1.0       312.0           2           3
# 2          13.0             1         2.0       482.0           2           3
# 3          12.0             1         2.0       470.0           2           3
# 4          18.0             3         2.0       506.0           2           3
# 5          17.0             1         2.0       440.0           2           3
# 6          18.0             1         2.0       420.0           2           3
# 7          12.0             1         2.0       393.0           2           3
# 8          20.0             2         2.0       506.0           2           3
# 9          40.0             1         2.0       525.0           2           3
# 10         11.0             1         2.0       511.0           2           3
# 11         39.0             2         1.0       264.0           2           3
# 12         13.0             2         1.0       320.0           2           3
# 13         35.0             2         2.0       440.0           2           3
# 14         35.0             2         1.0       308.0           2           3
#
#     PavedDrive  WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  \
# 0            2         140            0              0          0
# 1            2         393           36              0          0
# 2            2         212           34              0          0
# 3            2         360           36              0          0
# 4            2           0           82              0          0
# 5            2         157           84              0          0
# 6            2         483           21              0          0
# 7            2           0           75              0          0
# 8            2         192            0              0          0
# 9            2         240            0              0          0
# 10           2         203           68              0          0
# 11           2         275            0              0          0
# 12           2           0            0              0          0
# 13           2         173            0              0          0
# 14           2           0           30              0          0
#
#     ScreenPorch  PoolArea  PoolQC  Fence  MiscFeature  MiscVal  MoSold  \
# 0           120         0       1      2            1        0       6
# 1             0         0       1      1            0    12500       6
# 2             0         0       1      2            1        0       3
# 3             0         0       1      1            1        0       6
# 4           144         0       1      1            1        0       1
# 5             0         0       1      1            1        0       4
# 6             0         0       1      3            2      500       3
# 7             0         0       1      1            1        0       5
# 8             0         0       1      1            1        0       2
# 9             0         0       1      2            1        0       4
# 10            0         0       1      1            1        0       6
# 11            0         0       1      1            1        0       2
# 12            0         0       1      1            1        0       3
# 13            0         0       1      1            1        0       6
# 14            0         0       1      1            1        0       6
#
#     YrSold  SaleType  SaleCondition  SalePrice
# 0     2010         2              2  12.247694
# 1     2010         2              2  12.109011
# 2     2010         2              2  12.317167
# 3     2010         2              2  11.849398
# 4     2010         2              2  12.429216
# 5     2010         2              2  11.870600
# 6     2010         2              2  12.634603
# 7     2010         2              2  12.206073
# 8     2010         2              2  11.774520
# 9     2010         2              2  11.678440
# 10    2010         2              2  11.771436
# 11    2010         0              2  12.751300
# 12    2010         2              2  11.877569
# 13    2010         2              2  12.540758
# 14    2010         2              2  11.964001

# %%
dataset_test.head(15)
# Out:
#       Id  MSSubClass  MSZoning  LotFrontage   LotArea  Street  Alley  \
# 0   1461          20         4     4.382027  9.360655       0      1
# 1   1462          20         3     4.394449  9.565704       0      1
# 2   1463          60         3     4.304065  9.534595       0      1
# 3   1464          60         3     4.356709  9.208138       0      1
# 4   1465         120         3     3.761200  8.518193       0      1
# 5   1466          60         3     4.317488  9.210340       0      1
# 6   1467          20         3     4.204693  8.984694       0      1
# 7   1468          60         3     4.143135  9.036225       0      1
# 8   1469          20         3     4.442651  9.227787       0      1
# 9   1470          20         3     4.248495  9.035987       0      1
# 10  1471         120         4     3.258097  8.675564       0      1
# 11  1472         160         0     3.044522  7.426549       0      1
# 12  1473         160         0     3.044522  7.426549       0      1
# 13  1474         160         3     3.178054  7.731931       0      1
# 14  1475         120         3     3.178054  7.731931       0      1
#
#     LotShape  LandContour  Utilities  LotConfig  LandSlope  Neighborhood  \
# 0          0            3          1          1          1            16
# 1          1            3          1          2          1            16
# 2          1            3          1          1          1            19
# 3          1            3          1          1          1            19
# 4          1            2          1          1          1            20
# 5          1            3          1          2          1            19
# 6          1            3          1          1          1            19
# 7          1            3          1          1          1            19
# 8          0            3          1          1          1            19
# 9          0            3          1          2          1            16
# 10         1            3          1          0          1            16
# 11         0            3          1          1          1            14
# 12         0            3          1          1          1            14
# 13         0            3          1          0          1            14
# 14         0            3          1          0          1            14
#
#     Condition1  Condition2  BldgType  HouseStyle  OverallQual  OverallCond  \
# 0            3           0         0           3            5            6
# 1            2           0         0           3            6            6
# 2            2           0         0           2            5            5
# 3            2           0         0           2            6            6
# 4            2           0         2           3            8            5
# 5            2           0         0           2            6            5
# 6            2           0         0           3            6            7
# 7            2           0         0           2            6            5
# 8            2           0         0           3            7            5
# 9            2           0         0           3            4            5
# 10           2           0         2           3            7            5
# 11           2           0         1           2            6            5
# 12           2           0         1           2            5            5
# 13           2           0         1           2            6            6
# 14           2           0         1           3            7            6
#
#     YearBuilt  YearRemodAdd  RoofStyle  RoofMatl  Exterior1st  Exterior2nd  \
# 0        1961          1961          0         0            5            4
# 1        1958          1958          1         0            6            5
# 2        1997          1998          0         0            5            4
# 3        1998          1998          0         0            5            4
# 4        1992          1992          0         0            9            8
# 5        1993          1994          0         0            9            8
# 6        1992          2007          0         0            9            8
# 7        1998          1998          0         0            5            4
# 8        1990          1990          0         0            9            8
# 9        1970          1970          0         0            7            9
# 10       1999          1999          0         0            8            7
# 11       1971          1971          0         0            9            8
# 12       1971          1971          0         0            9            8
# 13       1975          1975          0         0            7           10
# 14       1975          1975          0         0            7           10
#
#     MasVnrType  MasVnrArea  ExterQual  ExterCond  Foundation  BsmtQual  \
# 0            2         0.0          3          2           2         4
# 1            1       108.0          3          2           2         4
# 2            2         0.0          3          2           3         2
# 3            1        20.0          3          2           3         4
# 4            2         0.0          0          2           3         2
# 5            2         0.0          3          2           3         2
# 6            2         0.0          3          3           3         2
# 7            2         0.0          3          2           3         2
# 8            2         0.0          3          2           3         2
# 9            2         0.0          3          2           2         4
# 10           2         0.0          0          2           3         2
# 11           1       504.0          3          2           2         4
# 12           1       492.0          3          2           2         4
# 13           2         0.0          3          2           2         4
# 14           2         0.0          3          2           2         2
#
#     BsmtCond  BsmtExposure  BsmtFinType1  BsmtFinSF1  BsmtFinType2  \
# 0          2             0             4       468.0             5
# 1          2             0             5       923.0             4
# 2          2             0             2       791.0             4
# 3          2             0             2       602.0             4
# 4          2             0             5       263.0             4
# 5          2             0             3         0.0             4
# 6          2             0             5       935.0             4
# 7          2             0             3         0.0             4
# 8          2             3             2       637.0             4
# 9          2             0             5       804.0             1
# 10         2             0             2      1051.0             6
# 11         2             0             4       156.0             4
# 12         2             0             4       300.0             4
# 13         2             0             5       514.0             4
# 14         2             0             3         0.0             4
#
#     BsmtFinSF2  BsmtUnfSF  TotalBsmtSF  Heating  HeatingQC  CentralAir  \
# 0        144.0      270.0        882.0        1          1           1
# 1          0.0      406.0       1329.0        1          1           1
# 2          0.0      137.0        928.0        1          4           1
# 3          0.0      324.0        926.0        1          3           1
# 4          0.0     1017.0       1280.0        1          3           1
# 5          0.0      763.0        763.0        1          4           1
# 6          0.0      233.0       1168.0        1          3           1
# 7          0.0      789.0        789.0        1          4           1
# 8          0.0      663.0       1300.0        1          4           1
# 9         78.0        0.0        882.0        1          1           1
# 10         0.0      354.0       1405.0        1          3           1
# 11         0.0      327.0        483.0        1          1           1
# 12         0.0      225.0        525.0        1          1           1
# 13         0.0      341.0        855.0        1          1           1
# 14         0.0      836.0        836.0        1          3           1
#
#     Electrical  1stFlrSF  2ndFlrSF  LowQualFinSF  GrLivArea  BsmtFullBath  \
# 0            2  6.797940         0             0   6.797940           0.0
# 1            2  7.192182         0             0   7.192182           0.0
# 2            2  6.833032       701             0   7.395722           0.0
# 3            2  6.830874       678             0   7.380256           0.0
# 4            2  7.154615         0             0   7.154615           0.0
# 5            2  6.637258       892             0   7.411556           0.0
# 6            2  7.079184         0             0   7.079184           1.0
# 7            2  6.670766       676             0   7.289611           0.0
# 8            2  7.201171         0             0   7.201171           1.0
# 9            2  6.782192         0             0   6.782192           1.0
# 10           2  7.198184         0             0   7.198184           1.0
# 11           2  6.180017       504             0   6.894670           0.0
# 12           2  6.263398       567             0   6.995766           0.0
# 13           2  6.751101       601             0   7.283448           0.0
# 14           2  6.728629         0             0   6.728629           0.0
#
#     BsmtHalfBath  FullBath  HalfBath  BedroomAbvGr  KitchenAbvGr  KitchenQual  \
# 0            0.0         1         0             2             1            1
# 1            0.0         1         1             3             1            2
# 2            0.0         2         1             3             1            1
# 3            0.0         2         1             3             1            2
# 4            0.0         2         0             2             1            2
# 5            0.0         2         1             3             1            1
# 6            0.0         2         0             3             1            1
# 7            0.0         2         1             3             1            1
# 8            0.0         1         1             2             1            2
# 9            0.0         1         0             2             1            1
# 10           0.0         2         0             2             1            2
# 11           0.0         1         1             2             1            1
# 12           0.0         1         1             3             1            1
# 13           0.0         2         1             3             1            2
# 14           0.0         1         0             2             1            1
#
#     TotRmsAbvGrd  Functional  Fireplaces  FireplaceQu  GarageType  \
# 0              5           3           0            1           3
# 1              6           3           0            1           3
# 2              6           3           1            5           3
# 3              7           3           1            2           3
# 4              5           3           0            1           3
# 5              7           3           1            5           3
# 6              6           3           0            1           3
# 7              7           3           1            2           3
# 8              5           3           1            3           3
# 9              4           3           0            1           3
# 10             5           3           1            0           3
# 11             5           3           0            1           1
# 12             6           3           0            1           1
# 13             6           3           1            5           3
# 14             4           3           0            1           3
#
#     GarageYrBlt  GarageFinish  GarageCars  GarageArea  GarageQual  GarageCond  \
# 0        1961.0             2         1.0       730.0           2           3
# 1        1958.0             2         1.0       312.0           2           3
# 2        1997.0             1         2.0       482.0           2           3
# 3        1998.0             1         2.0       470.0           2           3
# 4        1992.0             3         2.0       506.0           2           3
# 5        1993.0             1         2.0       440.0           2           3
# 6        1992.0             1         2.0       420.0           2           3
# 7        1998.0             1         2.0       393.0           2           3
# 8        1990.0             2         2.0       506.0           2           3
# 9        1970.0             1         2.0       525.0           2           3
# 10       1999.0             1         2.0       511.0           2           3
# 11       1971.0             2         1.0       264.0           2           3
# 12       1997.0             2         1.0       320.0           2           3
# 13       1975.0             2         2.0       440.0           2           3
# 14       1975.0             2         1.0       308.0           2           3
#
#     PavedDrive  WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  \
# 0            2         140            0              0          0
# 1            2         393           36              0          0
# 2            2         212           34              0          0
# 3            2         360           36              0          0
# 4            2           0           82              0          0
# 5            2         157           84              0          0
# 6            2         483           21              0          0
# 7            2           0           75              0          0
# 8            2         192            0              0          0
# 9            2         240            0              0          0
# 10           2         203           68              0          0
# 11           2         275            0              0          0
# 12           2           0            0              0          0
# 13           2         173            0              0          0
# 14           2           0           30              0          0
#
#     ScreenPorch  PoolArea  PoolQC  Fence  MiscFeature  MiscVal  MoSold  \
# 0           120         0       1      2            1        0       6
# 1             0         0       1      1            0    12500       6
# 2             0         0       1      2            1        0       3
# 3             0         0       1      1            1        0       6
# 4           144         0       1      1            1        0       1
# 5             0         0       1      1            1        0       4
# 6             0         0       1      3            2      500       3
# 7             0         0       1      1            1        0       5
# 8             0         0       1      1            1        0       2
# 9             0         0       1      2            1        0       4
# 10            0         0       1      1            1        0       6
# 11            0         0       1      1            1        0       2
# 12            0         0       1      1            1        0       3
# 13            0         0       1      1            1        0       6
# 14            0         0       1      1            1        0       6
#
#     YrSold  SaleType  SaleCondition  SalePrice
# 0     2010         2              2  12.247694
# 1     2010         2              2  12.109011
# 2     2010         2              2  12.317167
# 3     2010         2              2  11.849398
# 4     2010         2              2  12.429216
# 5     2010         2              2  11.870600
# 6     2010         2              2  12.634603
# 7     2010         2              2  12.206073
# 8     2010         2              2  11.774520
# 9     2010         2              2  11.678440
# 10    2010         2              2  11.771436
# 11    2010         0              2  12.751300
# 12    2010         2              2  11.877569
# 13    2010         2              2  12.540758
# 14    2010         2              2  11.964001

# %%
# storing the features from dataset_train for feature scaling 

scaling_features_for_train = [feature for feature in dataset_train.columns if feature not in ["Id", "SalePrice"]]
len(scaling_features_for_train)
# Out:
# 79

# %%
from sklearn.preprocessing import MinMaxScaler
scalar_for_train = MinMaxScaler()
scalar_for_train.fit(dataset_train[scaling_features_for_train])
# Out:
# MinMaxScaler()

# %%
scalar_for_train.transform(dataset_train[scaling_features_for_train])
# Out:
# array([[0.        , 1.        , 0.59344538, ..., 1.        , 0.5       ,
#         0.5       ],
#        [0.        , 0.75      , 0.59895721, ..., 1.        , 0.5       ,
#         0.5       ],
#        [0.23529412, 0.75      , 0.55885415, ..., 1.        , 0.5       ,
#         0.5       ],
#        ...,
#        [0.        , 0.75      , 0.90099208, ..., 0.        , 0.5       ,
#         0.        ],
#        [0.38235294, 0.75      , 0.48035069, ..., 0.        , 0.5       ,
#         0.5       ],
#        [0.23529412, 0.75      , 0.55885415, ..., 0.        , 0.5       ,
#         0.5       ]])

# %%
data_for_train = pd.concat([dataset_train[['Id', 'SalePrice']].reset_index(drop = True), pd.DataFrame(scalar_for_train.transform(dataset_train[scaling_features_for_train]), columns = scaling_features_for_train)], axis = 1)

# %%
data_for_train.head()
# Out:
#      Id  SalePrice  MSSubClass  MSZoning  LotFrontage   LotArea  Street  \
# 0  1461  12.247694    0.000000      1.00     0.593445  0.566360     0.0
# 1  1462  12.109011    0.000000      0.75     0.598957  0.622527     0.0
# 2  1463  12.317167    0.235294      0.75     0.558854  0.614005     0.0
# 3  1464  11.849398    0.235294      0.75     0.582212  0.524583     0.0
# 4  1465  12.429216    0.588235      0.75     0.317987  0.335596     0.0
#
#    Alley  LotShape  LandContour  Utilities  LotConfig  LandSlope  \
# 0    0.5  0.000000     1.000000        1.0       0.25        0.5
# 1    0.5  0.333333     1.000000        1.0       0.50        0.5
# 2    0.5  0.333333     1.000000        1.0       0.25        0.5
# 3    0.5  0.333333     1.000000        1.0       0.25        0.5
# 4    0.5  0.333333     0.666667        1.0       0.25        0.5
#
#    Neighborhood  Condition1  Condition2  BldgType  HouseStyle  OverallQual  \
# 0          0.80    0.500000         0.0       0.0         0.6     0.444444
# 1          0.80    0.333333         0.0       0.0         0.6     0.555556
# 2          0.95    0.333333         0.0       0.0         0.4     0.444444
# 3          0.95    0.333333         0.0       0.0         0.4     0.555556
# 4          1.00    0.333333         0.0       0.5         0.6     0.777778
#
#    OverallCond  YearBuilt  YearRemodAdd  RoofStyle  RoofMatl  Exterior1st  \
# 0        0.625   0.384615      0.822581        0.0       0.0          0.5
# 1        0.625   0.407692      0.870968        0.5       0.0          0.6
# 2        0.500   0.107692      0.225806        0.0       0.0          0.5
# 3        0.625   0.100000      0.225806        0.0       0.0          0.5
# 4        0.500   0.146154      0.322581        0.0       0.0          0.9
#
#    Exterior2nd  MasVnrType  MasVnrArea  ExterQual  ExterCond  Foundation  \
# 0     0.363636        0.50    0.000000        1.0   0.666667        0.50
# 1     0.454545        0.25    0.083721        1.0   0.666667        0.50
# 2     0.363636        0.50    0.000000        1.0   0.666667        0.75
# 3     0.363636        0.25    0.015504        1.0   0.666667        0.75
# 4     0.727273        0.50    0.000000        0.0   0.666667        0.75
#
#    BsmtQual  BsmtCond  BsmtExposure  BsmtFinType1  BsmtFinSF1  BsmtFinType2  \
# 0       1.0       0.5           0.0      0.666667    0.116708      0.833333
# 1       1.0       0.5           0.0      0.833333    0.230175      0.666667
# 2       0.5       0.5           0.0      0.333333    0.197257      0.666667
# 3       1.0       0.5           0.0      0.333333    0.150125      0.666667
# 4       0.5       0.5           0.0      0.833333    0.065586      0.666667
#
#    BsmtFinSF2  BsmtUnfSF  TotalBsmtSF  Heating  HeatingQC  CentralAir  \
# 0    0.094364   0.126168     0.173111      1.0       0.25         1.0
# 1    0.000000   0.189720     0.260844      1.0       0.25         1.0
# 2    0.000000   0.064019     0.182139      1.0       1.00         1.0
# 3    0.000000   0.151402     0.181747      1.0       0.75         1.0
# 4    0.000000   0.475234     0.251227      1.0       0.75         1.0
#
#    Electrical  1stFlrSF  2ndFlrSF  LowQualFinSF  GrLivArea  BsmtFullBath  \
# 0    0.666667  0.312253  0.000000           0.0   0.312253           0.0
# 1    0.666667  0.468253  0.000000           0.0   0.468253           0.0
# 2    0.666667  0.326139  0.376477           0.0   0.548792           0.0
# 3    0.666667  0.325285  0.364125           0.0   0.542672           0.0
# 4    0.666667  0.453388  0.000000           0.0   0.453388           0.0
#
#    BsmtHalfBath  FullBath  HalfBath  BedroomAbvGr  KitchenAbvGr  KitchenQual  \
# 0           0.0      0.25       0.0      0.333333           0.5         0.25
# 1           0.0      0.25       0.5      0.500000           0.5         0.50
# 2           0.0      0.50       0.5      0.500000           0.5         0.25
# 3           0.0      0.50       0.5      0.500000           0.5         0.50
# 4           0.0      0.50       0.0      0.333333           0.5         0.50
#
#    TotRmsAbvGrd  Functional  Fireplaces  FireplaceQu  GarageType  GarageYrBlt  \
# 0      0.166667        0.75        0.00          0.2         0.5     0.792994
# 1      0.250000        0.75        0.00          0.2         0.5     0.802548
# 2      0.250000        0.75        0.25          1.0         0.5     0.678344
# 3      0.333333        0.75        0.25          0.4         0.5     0.675159
# 4      0.166667        0.75        0.00          0.2         0.5     0.694268
#
#    GarageFinish  GarageCars  GarageArea  GarageQual  GarageCond  PavedDrive  \
# 0      0.666667         0.2    0.490591    0.666667         1.0         1.0
# 1      0.666667         0.2    0.209677    0.666667         1.0         1.0
# 2      0.333333         0.4    0.323925    0.666667         1.0         1.0
# 3      0.333333         0.4    0.315860    0.666667         1.0         1.0
# 4      1.000000         0.4    0.340054    0.666667         1.0         1.0
#
#    WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  ScreenPorch  PoolArea  \
# 0    0.098315     0.000000            0.0        0.0     0.208333       0.0
# 1    0.275983     0.048518            0.0        0.0     0.000000       0.0
# 2    0.148876     0.045822            0.0        0.0     0.000000       0.0
# 3    0.252809     0.048518            0.0        0.0     0.000000       0.0
# 4    0.000000     0.110512            0.0        0.0     0.250000       0.0
#
#    PoolQC  Fence  MiscFeature   MiscVal    MoSold  YrSold  SaleType  \
# 0     1.0   0.50          0.5  0.000000  0.454545     1.0       0.5
# 1     1.0   0.25          0.0  0.735294  0.454545     1.0       0.5
# 2     1.0   0.50          0.5  0.000000  0.181818     1.0       0.5
# 3     1.0   0.25          0.5  0.000000  0.454545     1.0       0.5
# 4     1.0   0.25          0.5  0.000000  0.000000     1.0       0.5
#
#    SaleCondition
# 0            0.5
# 1            0.5
# 2            0.5
# 3            0.5
# 4            0.5

# %%
data_for_train.to_csv("X_train.csv", index = False)

# %%
# storing the features from dataset_test for feature scaling

scaling_feature_for_test = [feature for feature in dataset_test.columns if feature not in ["Id", "SalePrice"]]
len(scaling_feature_for_test)
# Out:
# 79

# %%
scalar_for_test = MinMaxScaler()
scalar_for_test.fit(dataset_test[scaling_feature_for_test])
# Out:
# MinMaxScaler()

# %%
scalar_for_test.transform(dataset_test[scaling_feature_for_test])
# Out:
# array([[0.        , 1.        , 0.59344538, ..., 1.        , 0.5       ,
#         0.5       ],
#        [0.        , 0.75      , 0.59895721, ..., 1.        , 0.5       ,
#         0.5       ],
#        [0.23529412, 0.75      , 0.55885415, ..., 1.        , 0.5       ,
#         0.5       ],
#        ...,
#        [0.        , 0.75      , 0.90099208, ..., 0.        , 0.5       ,
#         0.        ],
#        [0.38235294, 0.75      , 0.48035069, ..., 0.        , 0.5       ,
#         0.5       ],
#        [0.23529412, 0.75      , 0.55885415, ..., 0.        , 0.5       ,
#         0.5       ]])

# %%
data_for_test = pd.concat([dataset_test[["Id", "SalePrice"]].reset_index(drop = False), pd.DataFrame(scalar_for_test.transform(dataset_test[scaling_feature_for_test]), columns = scaling_feature_for_test)], axis = 1)

# %%
data_for_test.head()
# Out:
#    index    Id  SalePrice  MSSubClass  MSZoning  LotFrontage   LotArea  \
# 0      0  1461  12.247694    0.000000      1.00     0.593445  0.566360
# 1      1  1462  12.109011    0.000000      0.75     0.598957  0.622527
# 2      2  1463  12.317167    0.235294      0.75     0.558854  0.614005
# 3      3  1464  11.849398    0.235294      0.75     0.582212  0.524583
# 4      4  1465  12.429216    0.588235      0.75     0.317987  0.335596
#
#    Street  Alley  LotShape  LandContour  Utilities  LotConfig  LandSlope  \
# 0     0.0    0.5  0.000000     1.000000        1.0       0.25        0.5
# 1     0.0    0.5  0.333333     1.000000        1.0       0.50        0.5
# 2     0.0    0.5  0.333333     1.000000        1.0       0.25        0.5
# 3     0.0    0.5  0.333333     1.000000        1.0       0.25        0.5
# 4     0.0    0.5  0.333333     0.666667        1.0       0.25        0.5
#
#    Neighborhood  Condition1  Condition2  BldgType  HouseStyle  OverallQual  \
# 0          0.80    0.500000         0.0       0.0         0.6     0.444444
# 1          0.80    0.333333         0.0       0.0         0.6     0.555556
# 2          0.95    0.333333         0.0       0.0         0.4     0.444444
# 3          0.95    0.333333         0.0       0.0         0.4     0.555556
# 4          1.00    0.333333         0.0       0.5         0.6     0.777778
#
#    OverallCond  YearBuilt  YearRemodAdd  RoofStyle  RoofMatl  Exterior1st  \
# 0        0.625   0.625954      0.183333        0.0       0.0          0.5
# 1        0.625   0.603053      0.133333        0.5       0.0          0.6
# 2        0.500   0.900763      0.800000        0.0       0.0          0.5
# 3        0.625   0.908397      0.800000        0.0       0.0          0.5
# 4        0.500   0.862595      0.700000        0.0       0.0          0.9
#
#    Exterior2nd  MasVnrType  MasVnrArea  ExterQual  ExterCond  Foundation  \
# 0     0.363636        0.50    0.000000        1.0   0.666667        0.50
# 1     0.454545        0.25    0.083721        1.0   0.666667        0.50
# 2     0.363636        0.50    0.000000        1.0   0.666667        0.75
# 3     0.363636        0.25    0.015504        1.0   0.666667        0.75
# 4     0.727273        0.50    0.000000        0.0   0.666667        0.75
#
#    BsmtQual  BsmtCond  BsmtExposure  BsmtFinType1  BsmtFinSF1  BsmtFinType2  \
# 0       1.0       0.5           0.0      0.666667    0.116708      0.833333
# 1       1.0       0.5           0.0      0.833333    0.230175      0.666667
# 2       0.5       0.5           0.0      0.333333    0.197257      0.666667
# 3       1.0       0.5           0.0      0.333333    0.150125      0.666667
# 4       0.5       0.5           0.0      0.833333    0.065586      0.666667
#
#    BsmtFinSF2  BsmtUnfSF  TotalBsmtSF  Heating  HeatingQC  CentralAir  \
# 0    0.094364   0.126168     0.173111      1.0       0.25         1.0
# 1    0.000000   0.189720     0.260844      1.0       0.25         1.0
# 2    0.000000   0.064019     0.182139      1.0       1.00         1.0
# 3    0.000000   0.151402     0.181747      1.0       0.75         1.0
# 4    0.000000   0.475234     0.251227      1.0       0.75         1.0
#
#    Electrical  1stFlrSF  2ndFlrSF  LowQualFinSF  GrLivArea  BsmtFullBath  \
# 0    0.666667  0.312253  0.000000           0.0   0.312253           0.0
# 1    0.666667  0.468253  0.000000           0.0   0.468253           0.0
# 2    0.666667  0.326139  0.376477           0.0   0.548792           0.0
# 3    0.666667  0.325285  0.364125           0.0   0.542672           0.0
# 4    0.666667  0.453388  0.000000           0.0   0.453388           0.0
#
#    BsmtHalfBath  FullBath  HalfBath  BedroomAbvGr  KitchenAbvGr  KitchenQual  \
# 0           0.0      0.25       0.0      0.333333           0.5         0.25
# 1           0.0      0.25       0.5      0.500000           0.5         0.50
# 2           0.0      0.50       0.5      0.500000           0.5         0.25
# 3           0.0      0.50       0.5      0.500000           0.5         0.50
# 4           0.0      0.50       0.0      0.333333           0.5         0.50
#
#    TotRmsAbvGrd  Functional  Fireplaces  FireplaceQu  GarageType  GarageYrBlt  \
# 0      0.166667        0.75        0.00          0.2         0.5     0.211538
# 1      0.250000        0.75        0.00          0.2         0.5     0.201923
# 2      0.250000        0.75        0.25          1.0         0.5     0.326923
# 3      0.333333        0.75        0.25          0.4         0.5     0.330128
# 4      0.166667        0.75        0.00          0.2         0.5     0.310897
#
#    GarageFinish  GarageCars  GarageArea  GarageQual  GarageCond  PavedDrive  \
# 0      0.666667         0.2    0.490591    0.666667         1.0         1.0
# 1      0.666667         0.2    0.209677    0.666667         1.0         1.0
# 2      0.333333         0.4    0.323925    0.666667         1.0         1.0
# 3      0.333333         0.4    0.315860    0.666667         1.0         1.0
# 4      1.000000         0.4    0.340054    0.666667         1.0         1.0
#
#    WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  ScreenPorch  PoolArea  \
# 0    0.098315     0.000000            0.0        0.0     0.208333       0.0
# 1    0.275983     0.048518            0.0        0.0     0.000000       0.0
# 2    0.148876     0.045822            0.0        0.0     0.000000       0.0
# 3    0.252809     0.048518            0.0        0.0     0.000000       0.0
# 4    0.000000     0.110512            0.0        0.0     0.250000       0.0
#
#    PoolQC  Fence  MiscFeature   MiscVal    MoSold  YrSold  SaleType  \
# 0     1.0   0.50          0.5  0.000000  0.454545     1.0       0.5
# 1     1.0   0.25          0.0  0.735294  0.454545     1.0       0.5
# 2     1.0   0.50          0.5  0.000000  0.181818     1.0       0.5
# 3     1.0   0.25          0.5  0.000000  0.454545     1.0       0.5
# 4     1.0   0.25          0.5  0.000000  0.000000     1.0       0.5
#
#    SaleCondition
# 0            0.5
# 1            0.5
# 2            0.5
# 3            0.5
# 4            0.5

# %%
data_for_test.to_csv("X_test.csv", index = False)
